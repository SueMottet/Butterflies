# %%
#  Import and read
import pandas as pd 
import numpy as np
import json
# Sue Mottet 2-11-2022

# %%
# Import dependencies.
import matplotlib.pyplot as plt
import numpy as np

# %%
import datetime

x = datetime. datetime(2018, 9, 15)
print(x. strftime("%b %d %Y %H:%M:%S"))
# Out:
# Sep 15 2018 00:00:00

# %%
sighting_season_start = datetime. datetime(2021, 1, 1)

# %%
sighting_season_end = datetime. datetime(2021, 12, 31)
print(sighting_season_end. strftime("%b %d %Y %H:%M:%S"))
# Out:
# Dec 31 2021 00:00:00

# %%
tagging_season_start = datetime. datetime(2021, 8, 1)
print(tagging_season_start. strftime("%b %d %Y %H:%M:%S"))
# Out:
# Aug 01 2021 00:00:00

# %%
tagging_season_end  = datetime. datetime(2021, 12, 31)
print(tagging_season_end. strftime("%b %d %Y %H:%M:%S"))
# Out:
# Dec 31 2021 00:00:00

# %%
mexico_tag_recovery_season = 2021
# print(mexico_tag_recovery_season. strftime("%b %d %Y %H:%M:%S"))
mexico_tag_recovery_season
# Out:
# 2021

# %%
domestic_tag_recovery_start = datetime. datetime(2021, 8, 1)
print(domestic_tag_recovery_start. strftime("%b %d %Y %H:%M:%S"))
# Out:
# Aug 01 2021 00:00:00

# %%
domestic_tag_recovery_end  = datetime. datetime(2022, 4, 1)
print(domestic_tag_recovery_end. strftime("%b %d %Y %H:%M:%S"))
# Out:
# Apr 01 2022 00:00:00

# %% [markdown]
# # Journey North - Large Dataset

# %%
JNorth1996_2020_df = pd.read_csv("../../resources/JNorth/UWMadisonArb_JNorth_Project_MonarchsAndMilkweed_1996-2020.csv")
JNorth1996_2020_df.head()
# Out:
# C:\Users\motte\anaconda3\envs\mlenv\lib\site-packages\IPython\core\interactiveshell.py:3444: DtypeWarning: Columns (8) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
#           id sighting_date                species  number  latitude  \
# 0  850841703    1996-12-16  Monarch Adult Sighted       1    27.594
# 1  851824801    1996-12-06  Monarch Adult Sighted       1    30.420
# 2  854409931    1996-09-21  Monarch Adult Sighted       1    40.817
# 3  854557206    1996-09-21  Monarch Adult Sighted       1    40.817
# 4  855061862    1997-01-01  Monarch Adult Sighted       1    34.244
#
#    longitude  flag_location  \
# 0    -81.362              0
# 1    -87.224              0
# 2    -96.710              0
# 3    -96.710              0
# 4    -77.946              0
#
#                                             comments  \
# 0  On the ballfield a solitary monarch butterfly ...
# ...

# %%
JNorth1996_2020_df.columns.tolist()
# Out:
# ['id',
#  'sighting_date',
#  'species',
#  'number',
#  'latitude',
#  'longitude',
#  'flag_location',
#  'comments',
#  'school',
#  'grade',
#  'image_url',
#  'customerid',
#  'number_old',
#  'flag_number',
#  'species_old',
#  'flag_species']

# %%
cols = ['id', 'sighting_date', 'species', 'number', 'latitude', 'longitude']

# %%
JNorth1996_2020_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 227433 entries, 0 to 227432
# Data columns (total 16 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   id             227433 non-null  int64
#  1   sighting_date  227433 non-null  object
#  2   species        227433 non-null  object
#  3   number         227433 non-null  int64
#  4   latitude       227433 non-null  float64
#  5   longitude      227433 non-null  float64
#  6   flag_location  227433 non-null  int64
#  7   comments       227433 non-null  object
#  8   school         227433 non-null  object
#  9   grade          227433 non-null  float64
#  10  image_url      227433 non-null  object
#  11  customerid     227433 non-null  int64
#  12  number_old     227433 non-null  float64
#  13  flag_number    227433 non-null  int64
#  14  species_old    227433 non-null  object
#  15  flag_species   227433 non-null  int64
# dtypes: float64(4), int64(6), object(6)
# ...

# %%
str(JNorth1996_2020_df.columns.tolist())
# Out:
# "['id', 'sighting_date', 'species', 'number', 'latitude', 'longitude', 'flag_location', 'comments', 'school', 'grade', 'image_url', 'customerid', 'number_old', 'flag_number', 'species_old', 'flag_species']"

# %%
JNorth1996_2020_df.describe()
# Out:
#                  id        number       latitude      longitude  \
# count  2.274330e+05  2.274330e+05  227433.000000  227433.000000
# mean   1.420650e+09  1.186529e+02      38.400690     -87.569965
# std    1.456887e+08  2.209080e+04       5.268651      10.880362
# min    8.508417e+08 -1.700000e+01     -12.100000    -165.107000
# 25%    1.377751e+09  1.000000e+00      34.723000     -95.268000
# 50%    1.477448e+09  1.000000e+00      39.503000     -86.787000
# 75%    1.526383e+09  3.000000e+00      42.409000     -79.255000
# max    1.526525e+09  1.000000e+07      65.136000     -52.883000
#
#        flag_location          grade    customerid    number_old  \
# count  227433.000000  227433.000000  2.274330e+05  2.274330e+05
# mean        0.598018 -907386.217597  9.451737e+06 -2.844270e+05
# std         0.490299  289894.342744  2.193961e+06  4.518136e+05
# min         0.000000 -999999.999000  0.000000e+00 -1.000000e+06
# 25%         0.000000 -999999.999000  9.941050e+06 -1.000000e+06
# ...

# %%
JNorth1996_2020_df.columns.tolist()
# Out:
# ['id',
#  'sighting_date',
#  'species',
#  'number',
#  'latitude',
#  'longitude',
#  'flag_location',
#  'comments',
#  'school',
#  'grade',
#  'image_url',
#  'customerid',
#  'number_old',
#  'flag_number',
#  'species_old',
#  'flag_species']

# %%
print(JNorth1996_2020_df.shape)
# Out:
# (227433, 16)

# %%
# Determine the number of unique values in each column.
for col in JNorth1996_2020_df:
  print(JNorth1996_2020_df[col].unique())
# Out:
# [ 850841703  851824801  854409931 ... 1526524404 1526524405 1526525021]
# ['1996-12-16' '1996-12-06' '1996-09-21' ... '2020-12-29' '2020-12-30'
#  '2020-12-31']
# ['Monarch Adult Sighted' 'Monarch Adult (FIRST sighted)'
#  'Monarch Egg (FIRST sighted)' 'Monarch (OTHER Observations)'
#  'Monarch Larva (FIRST sighted)' 'Monarch PEAK Migration'
#  'Milkweed (FIRST sighted)' 'Monarch Fall Roost' 'Monarch Egg Sighted'
#  'Monarch Larva Sighted' 'Monarch, Captive-Reared' 'Milkweed Sighted']
# [       1      150       20       89       30     2000       50     7500
#        23      200        5      300        4      100       71      120
#       325       21       28     5000    20000       36       25        6
#        54     1000      160       24       60       37        2     3000
#   1000000       10  2000000       40       85       65       15        8
#       500       14      112       75       80    15000       18    10000
# ...

# %%
# Determine the number of unique values in each column.
for col in JNorth1996_2020_df:
  print(JNorth1996_2020_df[col].value_counts())
# Out:
# 850841703     1
# 1526350827    1
# 1526350816    1
# 1526350817    1
# 1526350818    1
#              ..
# 1432512422    1
# 1432519704    1
# 1432562236    1
# 1432562641    1
# 1526525021    1
# Name: id, Length: 227433, dtype: int64
# 2018-08-22    392
# 2018-10-03    377
# 2018-09-06    353
# 2019-09-19    337
# 2018-09-12    335
#              ...
# 2015-12-31      1
# 2015-11-24      1
# 2015-11-22      1
# 2006-07-30      1
# 1996-12-16      1
# Name: sighting_date, Length: 7491, dtype: int64
# Monarch Adult Sighted            102306
# Monarch Adult (FIRST sighted)     36409
# Monarch Larva Sighted             17378
# Monarch, Captive-Reared           14339
# Monarch (OTHER Observations)      13581
# Monarch Egg Sighted                8736
# Milkweed (FIRST sighted)           8465
# Monarch PEAK Migration             7689
# Monarch Egg (FIRST sighted)        6876
# Monarch Fall Roost                 5035
# Monarch Larva (FIRST sighted)      4898
# ...

# %%
# Find null values
for column in JNorth1996_2020_df.columns:
   print(f"Column {column} has {JNorth1996_2020_df[column].isnull().sum()} null values")
# Out:
# Column id has 0 null values
# Column sighting_date has 0 null values
# Column species has 0 null values
# Column number has 0 null values
# Column latitude has 0 null values
# Column longitude has 0 null values
# Column flag_location has 0 null values
# Column comments has 0 null values
# Column school has 0 null values
# Column grade has 0 null values
# Column image_url has 0 null values
# Column customerid has 0 null values
# Column number_old has 0 null values
# Column flag_number has 0 null values
# Column species_old has 0 null values
# Column flag_species has 0 null values

# %%
# Find duplicate entries
print(f"Duplicate entries: {JNorth1996_2020_df.duplicated().sum()}")
# Out:
# Duplicate entries: 0

# %%
# JNorth1996_2020_df= pd.DataFrame(JNorth_Adult_Site_df)
JNorth1996_2020_df.drop(['id','flag_location', 'comments','school','grade','image_url','customerid','number_old','flag_number','species_old','flag_species'], axis=1, inplace=True)
JNorth1996_2020_df.head()
# Out:
#   sighting_date                species  number  latitude  longitude
# 0    1996-12-16  Monarch Adult Sighted       1    27.594    -81.362
# 1    1996-12-06  Monarch Adult Sighted       1    30.420    -87.224
# 2    1996-09-21  Monarch Adult Sighted       1    40.817    -96.710
# 3    1996-09-21  Monarch Adult Sighted       1    40.817    -96.710
# 4    1997-01-01  Monarch Adult Sighted       1    34.244    -77.946

# %%
JNorthTwentyOrLess = JNorth1996_2020_df.loc[(JNorth1996_2020_df['latitude']<=20)]
JNorthTwentyOrLess = pd.DataFrame(JNorthTwentyOrLess)
JNorthTwentyOrLess['lat_range'] = '20_OR_LESS'
JNorthTwentyOrLess
# Out:
#        sighting_date                        species  number  latitude  \
# 1563      1998-10-18          Monarch Adult Sighted       1    19.620
# 1564      1998-10-19          Monarch Adult Sighted       1    19.500
# 2822      1999-10-21  Monarch Adult (FIRST sighted)       1    19.620
# 3031      2000-03-16  Monarch Adult (FIRST sighted)       1    19.467
# 4275      2000-10-22         Monarch PEAK Migration       1    19.500
# ...              ...                            ...     ...       ...
# 226667    2020-11-18          Monarch Adult Sighted       1    17.717
# 226701    2020-11-21          Monarch Adult Sighted       1    17.722
# 226715    2020-11-22   Monarch (OTHER Observations)       1    18.909
# 226716    2020-11-21          Monarch Adult Sighted       1    18.911
# 227031    2020-12-17          Monarch Adult Sighted       1    17.714
#
#         longitude   lat_range
# 1563     -100.285  20_OR_LESS
# 1564     -100.285  20_OR_LESS
# 2822     -100.285  20_OR_LESS
# ...

# %%
JNorthTwentyOneToTwentyFive = JNorth1996_2020_df.loc[(JNorth1996_2020_df['latitude']>20) & (JNorth1996_2020_df['latitude']<=25)]
JNorthTwentyOneToTwentyFive = pd.DataFrame(JNorthTwentyOneToTwentyFive)
JNorthTwentyOneToTwentyFive['lat_range'] = '20+_TO_25'
JNorthTwentyOneToTwentyFive
# Out:
#        sighting_date                        species  number  latitude  \
# 2824      1999-10-19  Monarch Adult (FIRST sighted)       1    22.750
# 2845      1999-10-16  Monarch Adult (FIRST sighted)       1    20.570
# 2846      1999-10-17  Monarch Adult (FIRST sighted)       1    22.090
# 2850      1999-10-10  Monarch Adult (FIRST sighted)       1    24.800
# 2852      1999-10-22  Monarch Adult (FIRST sighted)       1    20.200
# ...              ...                            ...     ...       ...
# 226071    2020-11-01   Monarch (OTHER Observations)       1    20.322
# 226072    2020-11-01   Monarch (OTHER Observations)      13    20.324
# 226162    2020-11-04             Monarch Fall Roost      50    20.690
# 227022    2020-12-17          Monarch Larva Sighted       6    24.551
# 227023    2020-12-17   Monarch (OTHER Observations)       4    24.551
#
#         longitude  lat_range
# 2824     -101.000  20+_TO_25
# 2845     -102.230  20+_TO_25
# 2846     -100.590  20+_TO_25
# ...

# %%
JNorthTwentySixToThirty = JNorth1996_2020_df.loc[(JNorth1996_2020_df['latitude']>25) & (JNorth1996_2020_df['latitude']<=30)]
JNorthTwentySixToThirty = pd.DataFrame(JNorthTwentySixToThirty)
JNorthTwentySixToThirty['lat_range'] = '25+_TO_30'
JNorthTwentySixToThirty
# Out:
#        sighting_date                        species  number  latitude  \
# 0         1996-12-16          Monarch Adult Sighted       1    27.594
# 5         1997-02-04          Monarch Adult Sighted       1    27.500
# 6         1997-02-01          Monarch Adult Sighted       1    27.540
# 7         1997-02-06          Monarch Adult Sighted       1    27.500
# 8         1997-02-06          Monarch Adult Sighted       1    27.915
# ...              ...                            ...     ...       ...
# 227392    2020-12-30          Monarch Adult Sighted       1    29.218
# 227393    2020-12-30          Monarch Adult Sighted       1    29.218
# 227406    2020-03-29  Monarch Adult (FIRST sighted)       1    28.900
# 227409    2020-03-29  Monarch Adult (FIRST sighted)       1    28.900
# 227424    2020-03-01               Milkweed Sighted       1    29.577
#
#         longitude  lat_range
# 0         -81.362  25+_TO_30
# 5         -82.400  25+_TO_30
# 6         -82.470  25+_TO_30
# ...

# %%
JNorthThirtyOneToThirtyFive = JNorth1996_2020_df.loc[(JNorth1996_2020_df['latitude']>30) & (JNorth1996_2020_df['latitude']<=35)]
JNorthThirtyOneToThirtyFive = pd.DataFrame(JNorthThirtyOneToThirtyFive)
JNorthThirtyOneToThirtyFive['lat_range'] = '30+_TO_35'
JNorthThirtyOneToThirtyFive
# Out:
#        sighting_date                        species  number  latitude  \
# 1         1996-12-06          Monarch Adult Sighted       1    30.420
# 4         1997-01-01          Monarch Adult Sighted       1    34.244
# 20        1997-03-11          Monarch Adult Sighted       1    30.540
# 22        1997-03-12          Monarch Adult Sighted       1    30.230
# 24        1997-03-13          Monarch Adult Sighted       1    30.832
# ...              ...                            ...     ...       ...
# 227408    2020-12-25    Monarch Egg (FIRST sighted)       1    34.217
# 227422    2020-05-01        Monarch, Captive-Reared       1    30.536
# 227423    2020-05-01        Monarch, Captive-Reared       1    30.536
# 227426    2020-12-16  Monarch Adult (FIRST sighted)       2    33.849
# 227427    2020-12-18    Monarch Egg (FIRST sighted)      15    33.849
#
#         longitude  lat_range
# 1         -87.224  30+_TO_35
# 4         -77.946  30+_TO_35
# 20        -96.725  30+_TO_35
# ...

# %%
JNorthThirtySixToForty = JNorth1996_2020_df.loc[(JNorth1996_2020_df['latitude']>35) & (JNorth1996_2020_df['latitude']<=40)]
JNorthThirtySixToForty = pd.DataFrame(JNorthThirtySixToForty)
JNorthThirtySixToForty['lat_range'] = '35+_TO_40'
JNorthThirtySixToForty
# Out:
#        sighting_date                        species  number  latitude  \
# 49        1997-03-27          Monarch Adult Sighted       1    35.278
# 50        1997-03-30          Monarch Adult Sighted       1    35.758
# 58        1997-03-30          Monarch Adult Sighted       1    35.810
# 59        1997-04-02          Monarch Adult Sighted       1    35.988
# 60        1997-04-02          Monarch Adult Sighted       1    35.338
# ...              ...                            ...     ...       ...
# 227417    2020-09-01          Monarch Adult Sighted       3    39.807
# 227418    2020-09-10          Monarch Adult Sighted       6    39.807
# 227419    2020-09-16          Monarch Adult Sighted      23    39.805
# 227420    2020-04-06            Monarch Egg Sighted      10    35.276
# 227421    2020-10-20  Monarch Larva (FIRST sighted)       4    35.008
#
#         longitude  lat_range
# 49        -82.373  35+_TO_40
# 50        -78.778  35+_TO_40
# 58        -83.213  35+_TO_40
# ...

# %%
JNorthFortyOneToFortyFive = JNorth1996_2020_df.loc[(JNorth1996_2020_df['latitude']>40) & (JNorth1996_2020_df['latitude']<=45)]
JNorthFortyOneToFortyFive = pd.DataFrame(JNorthFortyOneToFortyFive)
JNorthFortyOneToFortyFive['lat_range'] = '4O+_TO_45'
JNorthFortyOneToFortyFive
# Out:
#        sighting_date                        species  number  latitude  \
# 2         1996-09-21          Monarch Adult Sighted       1    40.817
# 3         1996-09-21          Monarch Adult Sighted       1    40.817
# 53        1997-03-23          Monarch Adult Sighted       1    42.546
# 80        1997-04-03          Monarch Adult Sighted       1    41.648
# 103       1997-04-05          Monarch Adult Sighted       1    42.683
# ...              ...                            ...     ...       ...
# 227388    2020-06-01  Monarch Adult (FIRST sighted)       1    41.258
# 227425    2020-05-04               Milkweed Sighted       1    40.817
# 227430    2020-08-30          Monarch Larva Sighted       1    42.838
# 227431    2020-08-14          Monarch Adult Sighted       1    42.838
# 227432    2020-09-04          Monarch Adult Sighted       2    42.512
#
#         longitude  lat_range
# 2         -96.710  4O+_TO_45
# 3         -96.710  4O+_TO_45
# 53        -89.088  4O+_TO_45
# ...

# %%
JNorthFortySixToFifty = JNorth1996_2020_df.loc[(JNorth1996_2020_df['latitude']>45) & (JNorth1996_2020_df['latitude']<=50)]
JNorthFortySixToFifty = pd.DataFrame(JNorthFortySixToFifty)
JNorthFortySixToFifty['lat_range'] = '45+_TO_50'
JNorthFortySixToFifty
# Out:
#        sighting_date                  species  number  latitude  longitude  \
# 213       1997-05-09    Monarch Adult Sighted       1    45.883   -122.614
# 214       1997-05-11    Monarch Adult Sighted       1    45.883   -122.614
# 227       1997-05-17    Monarch Adult Sighted       1    45.109    -93.950
# 239       1997-05-27    Monarch Adult Sighted       1    45.516    -61.037
# 243       1997-05-11    Monarch Adult Sighted       1    45.976    -81.500
# ...              ...                      ...     ...       ...        ...
# 225638    2020-08-10  Monarch, Captive-Reared       1    45.679    -75.848
# 225639    2020-08-13  Monarch, Captive-Reared       2    45.635    -75.930
# 225640    2020-08-14  Monarch, Captive-Reared       1    45.679    -75.848
# 225641    2020-08-22  Monarch, Captive-Reared       1    45.679    -75.848
# 225643    2020-10-08    Monarch Adult Sighted       1    45.679    -75.848
#
#         lat_range
# 213     45+_TO_50
# 214     45+_TO_50
# ...

# %%
JNorth50PLUS = JNorth1996_2020_df.loc[(JNorth1996_2020_df['latitude']>50)]
JNorth50PLUS = pd.DataFrame(JNorth50PLUS)
JNorth50PLUS['lat_range'] = '5O+_OR_GREATER'
JNorth50PLUS
# Out:
#        sighting_date                        species  number  latitude  \
# 298       1997-06-15          Monarch Adult Sighted       1    52.660
# 319       1997-06-24          Monarch Adult Sighted       1    52.827
# 320       1997-06-10          Monarch Adult Sighted       1    50.180
# 809       1997-06-24  Monarch Adult (FIRST sighted)       1    50.450
# 810       1997-06-24  Monarch Adult (FIRST sighted)       1    52.590
# ...              ...                            ...     ...       ...
# 226854    2020-07-14          Monarch Larva Sighted       2    52.102
# 226855    2020-08-07        Monarch, Captive-Reared       2    52.102
# 226856    2020-08-07        Monarch, Captive-Reared       2    52.102
# 227428    2020-06-09          Monarch Adult Sighted       3    54.968
# 227429    2020-06-09          Monarch Adult Sighted       3    54.968
#
#         longitude       lat_range
# 298      -106.326  5O+_OR_GREATER
# 319      -106.873  5O+_OR_GREATER
# ...

# %%
frames = [JNorthTwentyOrLess, JNorthTwentyOneToTwentyFive, JNorthTwentySixToThirty,JNorthThirtyOneToThirtyFive, JNorthThirtySixToForty, JNorthFortyOneToFortyFive, JNorthFortySixToFifty,JNorth50PLUS]
JNorth1996_2020_df = pd.concat(frames)
JNorth1996_2020_df.tail(10)
# Out:
#        sighting_date                  species  number  latitude  longitude  \
# 220831    2020-09-22    Monarch Adult Sighted       1    51.353   -102.195
# 223753    2020-09-27    Monarch Adult Sighted       2    51.353   -102.191
# 224087    2020-10-09    Monarch Adult Sighted       1    51.353   -102.195
# 226852    2020-07-05      Monarch Egg Sighted       3    52.102   -106.637
# 226853    2020-07-12    Monarch Larva Sighted       2    52.102   -106.637
# 226854    2020-07-14    Monarch Larva Sighted       2    52.102   -106.637
# 226855    2020-08-07  Monarch, Captive-Reared       2    52.102   -106.637
# 226856    2020-08-07  Monarch, Captive-Reared       2    52.102   -106.637
# 227428    2020-06-09    Monarch Adult Sighted       3    54.968   -119.132
# 227429    2020-06-09    Monarch Adult Sighted       3    54.968   -119.132
#
#              lat_range
# 220831  5O+_OR_GREATER
# 223753  5O+_OR_GREATER
# 224087  5O+_OR_GREATER
# 226852  5O+_OR_GREATER
# ...

# %%
JNorth1996_2020_summary_df = JNorth1996_2020_df
JNorth1996_2020_summary_df['site'] = JNorth1996_2020_df[['latitude', 'longitude']].astype(str).agg('-'.join, axis=1)
JNorth1996_2020_summary_df
# Out:
#        sighting_date                        species  number  latitude  \
# 1563      1998-10-18          Monarch Adult Sighted       1    19.620
# 1564      1998-10-19          Monarch Adult Sighted       1    19.500
# 2822      1999-10-21  Monarch Adult (FIRST sighted)       1    19.620
# 3031      2000-03-16  Monarch Adult (FIRST sighted)       1    19.467
# 4275      2000-10-22         Monarch PEAK Migration       1    19.500
# ...              ...                            ...     ...       ...
# 226854    2020-07-14          Monarch Larva Sighted       2    52.102
# 226855    2020-08-07        Monarch, Captive-Reared       2    52.102
# 226856    2020-08-07        Monarch, Captive-Reared       2    52.102
# 227428    2020-06-09          Monarch Adult Sighted       3    54.968
# 227429    2020-06-09          Monarch Adult Sighted       3    54.968
#
#         longitude       lat_range             site
# 1563     -100.285      20_OR_LESS   19.62--100.285
# ...

# %%
JNorth1996_2020_summary_df.drop(['latitude','longitude'], axis=1, inplace=True)
JNorth1996_2020_summary_df.head()
# Out:
#      sighting_date                        species  number   lat_range  \
# 1563    1998-10-18          Monarch Adult Sighted       1  20_OR_LESS
# 1564    1998-10-19          Monarch Adult Sighted       1  20_OR_LESS
# 2822    1999-10-21  Monarch Adult (FIRST sighted)       1  20_OR_LESS
# 3031    2000-03-16  Monarch Adult (FIRST sighted)       1  20_OR_LESS
# 4275    2000-10-22         Monarch PEAK Migration       1  20_OR_LESS
#
#                 site
# 1563  19.62--100.285
# 1564   19.5--100.285
# 2822  19.62--100.285
# 3031  19.467--100.35
# 4275      19.5--99.0

# %%
JNorth1996_2020_summary_df['year'] = pd.DatetimeIndex(JNorth1996_2020_summary_df['sighting_date']).year
JNorth1996_2020_summary_df
# Out:
#        sighting_date                        species  number       lat_range  \
# 1563      1998-10-18          Monarch Adult Sighted       1      20_OR_LESS
# 1564      1998-10-19          Monarch Adult Sighted       1      20_OR_LESS
# 2822      1999-10-21  Monarch Adult (FIRST sighted)       1      20_OR_LESS
# 3031      2000-03-16  Monarch Adult (FIRST sighted)       1      20_OR_LESS
# 4275      2000-10-22         Monarch PEAK Migration       1      20_OR_LESS
# ...              ...                            ...     ...             ...
# 226854    2020-07-14          Monarch Larva Sighted       2  5O+_OR_GREATER
# 226855    2020-08-07        Monarch, Captive-Reared       2  5O+_OR_GREATER
# 226856    2020-08-07        Monarch, Captive-Reared       2  5O+_OR_GREATER
# 227428    2020-06-09          Monarch Adult Sighted       3  5O+_OR_GREATER
# 227429    2020-06-09          Monarch Adult Sighted       3  5O+_OR_GREATER
#
#                    site  year
# ...

# %%
JNorth1996_2020_summary_df['month'] = pd.DatetimeIndex(JNorth1996_2020_summary_df['sighting_date']).month
JNorth1996_2020_summary_df
# Out:
#        sighting_date                        species  number       lat_range  \
# 1563      1998-10-18          Monarch Adult Sighted       1      20_OR_LESS
# 1564      1998-10-19          Monarch Adult Sighted       1      20_OR_LESS
# 2822      1999-10-21  Monarch Adult (FIRST sighted)       1      20_OR_LESS
# 3031      2000-03-16  Monarch Adult (FIRST sighted)       1      20_OR_LESS
# 4275      2000-10-22         Monarch PEAK Migration       1      20_OR_LESS
# ...              ...                            ...     ...             ...
# 226854    2020-07-14          Monarch Larva Sighted       2  5O+_OR_GREATER
# 226855    2020-08-07        Monarch, Captive-Reared       2  5O+_OR_GREATER
# 226856    2020-08-07        Monarch, Captive-Reared       2  5O+_OR_GREATER
# 227428    2020-06-09          Monarch Adult Sighted       3  5O+_OR_GREATER
# 227429    2020-06-09          Monarch Adult Sighted       3  5O+_OR_GREATER
#
#                    site  year  month
# ...

# %% [markdown]
# # Adult Sightings Pivot

# %%
# filtering by type of observation (Monarch Adult Sighted)
JNorth_Adult_Site_df = JNorth1996_2020_df[JNorth1996_2020_df['species']=='Monarch Adult Sighted']
JNorth_Adult_Site_df.head()
# Out:
#       sighting_date                species  number   lat_range  \
# 1563     1998-10-18  Monarch Adult Sighted       1  20_OR_LESS
# 1564     1998-10-19  Monarch Adult Sighted       1  20_OR_LESS
# 11369    2004-01-01  Monarch Adult Sighted       1  20_OR_LESS
# 13268    2005-01-01  Monarch Adult Sighted       1  20_OR_LESS
# 16342    2006-01-01  Monarch Adult Sighted       1  20_OR_LESS
#
#                  site  year  month
# 1563   19.62--100.285  1998     10
# 1564    19.5--100.285  1998     10
# 11369  19.62--100.285  2004      1
# 13268  19.62--100.285  2005      1
# 16342  19.62--100.285  2006      1

# %%
JNorth_Adult_Site_dt_df = JNorth_Adult_Site_df.groupby(['month','year','species', 'lat_range'])['sighting_date'].count().reset_index()
JNorth_Adult_Site_dt_df = pd.DataFrame(JNorth_Adult_Site_dt_df)

# %%
JNorth_Adult_Site_dt_df
# Out:
#      month  year                species   lat_range  sighting_date
# 0        1  1997  Monarch Adult Sighted   30+_TO_35              1
# 1        1  2002  Monarch Adult Sighted   25+_TO_30              5
# 2        1  2002  Monarch Adult Sighted   30+_TO_35              2
# 3        1  2002  Monarch Adult Sighted   35+_TO_40              3
# 4        1  2003  Monarch Adult Sighted   25+_TO_30              5
# ..     ...   ...                    ...         ...            ...
# 837     12  2019  Monarch Adult Sighted   35+_TO_40              2
# 838     12  2020  Monarch Adult Sighted  20_OR_LESS              1
# 839     12  2020  Monarch Adult Sighted   25+_TO_30            206
# 840     12  2020  Monarch Adult Sighted   30+_TO_35            116
# 841     12  2020  Monarch Adult Sighted   35+_TO_40              7
#
# [842 rows x 5 columns]

# %%
JNorth_Adult_Site_dt_df.rename(columns={'sighting_date': 'adult_sight_dates'}, inplace=True)
JNorth_Adult_Site_dt_df
# Out:
#      month  year                species   lat_range  adult_sight_dates
# 0        1  1997  Monarch Adult Sighted   30+_TO_35                  1
# 1        1  2002  Monarch Adult Sighted   25+_TO_30                  5
# 2        1  2002  Monarch Adult Sighted   30+_TO_35                  2
# 3        1  2002  Monarch Adult Sighted   35+_TO_40                  3
# 4        1  2003  Monarch Adult Sighted   25+_TO_30                  5
# ..     ...   ...                    ...         ...                ...
# 837     12  2019  Monarch Adult Sighted   35+_TO_40                  2
# 838     12  2020  Monarch Adult Sighted  20_OR_LESS                  1
# 839     12  2020  Monarch Adult Sighted   25+_TO_30                206
# 840     12  2020  Monarch Adult Sighted   30+_TO_35                116
# 841     12  2020  Monarch Adult Sighted   35+_TO_40                  7
#
# [842 rows x 5 columns]

# %%
JNorth1996_2020_adultsite_d_dates = JNorth_Adult_Site_df.groupby(['month','year','species', 'lat_range'])['sighting_date'].nunique().reset_index()
JNorth1996_2020_adultsite_d_dates = pd.DataFrame(JNorth1996_2020_adultsite_d_dates)
JNorth1996_2020_adultsite_d_dates
# Out:
#      month  year                species   lat_range  sighting_date
# 0        1  1997  Monarch Adult Sighted   30+_TO_35              1
# 1        1  2002  Monarch Adult Sighted   25+_TO_30              4
# 2        1  2002  Monarch Adult Sighted   30+_TO_35              2
# 3        1  2002  Monarch Adult Sighted   35+_TO_40              3
# 4        1  2003  Monarch Adult Sighted   25+_TO_30              5
# ..     ...   ...                    ...         ...            ...
# 837     12  2019  Monarch Adult Sighted   35+_TO_40              2
# 838     12  2020  Monarch Adult Sighted  20_OR_LESS              1
# 839     12  2020  Monarch Adult Sighted   25+_TO_30             30
# 840     12  2020  Monarch Adult Sighted   30+_TO_35             26
# 841     12  2020  Monarch Adult Sighted   35+_TO_40              6
#
# [842 rows x 5 columns]

# %%
JNorth1996_2020_adultsite_d_dates.rename(columns={'sighting_date': 'adult_sight_distinct_dates'}, inplace=True)
JNorth1996_2020_adultsite_d_dates
# Out:
#      month  year                species   lat_range  \
# 0        1  1997  Monarch Adult Sighted   30+_TO_35
# 1        1  2002  Monarch Adult Sighted   25+_TO_30
# 2        1  2002  Monarch Adult Sighted   30+_TO_35
# 3        1  2002  Monarch Adult Sighted   35+_TO_40
# 4        1  2003  Monarch Adult Sighted   25+_TO_30
# ..     ...   ...                    ...         ...
# 837     12  2019  Monarch Adult Sighted   35+_TO_40
# 838     12  2020  Monarch Adult Sighted  20_OR_LESS
# 839     12  2020  Monarch Adult Sighted   25+_TO_30
# 840     12  2020  Monarch Adult Sighted   30+_TO_35
# 841     12  2020  Monarch Adult Sighted   35+_TO_40
#
#      adult_sight_distinct_dates
# 0                             1
# 1                             4
# 2                             2
# 3                             3
# 4                             5
# ..                          ...
# 837                           2
# 838                           1
# 839                          30
# ...

# %%
JNorth1996_2020_adultsite_species =JNorth_Adult_Site_df.groupby(['month','year','species', 'lat_range'])['number'].sum().reset_index()
JNorth1996_2020_adultsite_species
# Out:
#      month  year                species   lat_range  number
# 0        1  1997  Monarch Adult Sighted   30+_TO_35       1
# 1        1  2002  Monarch Adult Sighted   25+_TO_30       5
# 2        1  2002  Monarch Adult Sighted   30+_TO_35       2
# 3        1  2002  Monarch Adult Sighted   35+_TO_40       3
# 4        1  2003  Monarch Adult Sighted   25+_TO_30       5
# ..     ...   ...                    ...         ...     ...
# 837     12  2019  Monarch Adult Sighted   35+_TO_40       4
# 838     12  2020  Monarch Adult Sighted  20_OR_LESS       1
# 839     12  2020  Monarch Adult Sighted   25+_TO_30     372
# 840     12  2020  Monarch Adult Sighted   30+_TO_35     164
# 841     12  2020  Monarch Adult Sighted   35+_TO_40       9
#
# [842 rows x 5 columns]

# %%
JNorth_Adult_Site_dt_df['adult_sight_number']= JNorth1996_2020_adultsite_species['number']
JNorth_Adult_Site_dt_df['adult_sight_distinct_dates']= JNorth1996_2020_adultsite_d_dates['adult_sight_distinct_dates']
JNorth_Adult_Site_dt_df
# Out:
#      month  year                species   lat_range  adult_sight_dates  \
# 0        1  1997  Monarch Adult Sighted   30+_TO_35                  1
# 1        1  2002  Monarch Adult Sighted   25+_TO_30                  5
# 2        1  2002  Monarch Adult Sighted   30+_TO_35                  2
# 3        1  2002  Monarch Adult Sighted   35+_TO_40                  3
# 4        1  2003  Monarch Adult Sighted   25+_TO_30                  5
# ..     ...   ...                    ...         ...                ...
# 837     12  2019  Monarch Adult Sighted   35+_TO_40                  2
# 838     12  2020  Monarch Adult Sighted  20_OR_LESS                  1
# 839     12  2020  Monarch Adult Sighted   25+_TO_30                206
# 840     12  2020  Monarch Adult Sighted   30+_TO_35                116
# 841     12  2020  Monarch Adult Sighted   35+_TO_40                  7
#
#      adult_sight_number  adult_sight_distinct_dates
# 0                     1                           1
# ...

# %%
JNorth_Adult_Site_dt_df.drop(['species'], axis=1, inplace=True)
JNorth_Adult_Site_dt_df
# Out:
#      month  year   lat_range  adult_sight_dates  adult_sight_number  \
# 0        1  1997   30+_TO_35                  1                   1
# 1        1  2002   25+_TO_30                  5                   5
# 2        1  2002   30+_TO_35                  2                   2
# 3        1  2002   35+_TO_40                  3                   3
# 4        1  2003   25+_TO_30                  5                   5
# ..     ...   ...         ...                ...                 ...
# 837     12  2019   35+_TO_40                  2                   4
# 838     12  2020  20_OR_LESS                  1                   1
# 839     12  2020   25+_TO_30                206                 372
# 840     12  2020   30+_TO_35                116                 164
# 841     12  2020   35+_TO_40                  7                   9
#
#      adult_sight_distinct_dates
# 0                             1
# 1                             4
# 2                             2
# ...

# %%
JNorth_Adult_Site_dt_df.shape
# Out:
# (842, 6)

# %%
JNorth_Adult_Site_dt_df.to_csv('JNorth_Adult_Sighting_Summary_Pivot.csv', header=True, mode='w', index=False)

# %% [markdown]
# # Monarch Adult (FIRST sighted) Pivot

# %%
# filtering by type of observation (Monarch Adult First Sighted)
JNorth_AFirst_Site_df = JNorth1996_2020_df[JNorth1996_2020_df['species']=='Monarch Adult (FIRST sighted)']
JNorth_AFirst_Site_df.head()
# Out:
#       sighting_date                        species  number   lat_range  \
# 2822     1999-10-21  Monarch Adult (FIRST sighted)       1  20_OR_LESS
# 3031     2000-03-16  Monarch Adult (FIRST sighted)       1  20_OR_LESS
# 8451     2002-09-23  Monarch Adult (FIRST sighted)       1  20_OR_LESS
# 11243    2003-10-29  Monarch Adult (FIRST sighted)       1  20_OR_LESS
# 12290    2004-08-01  Monarch Adult (FIRST sighted)       1  20_OR_LESS
#
#                  site  year  month
# 2822   19.62--100.285  1999     10
# 3031   19.467--100.35  2000      3
# 8451    19.5--100.285  2002      9
# 11243  19.62--100.285  2003     10
# 12290  19.62--100.285  2004      8

# %%
JNorth_AFirst_Site_dt_df = JNorth_AFirst_Site_df.groupby(['month','year','species', 'lat_range'])['sighting_date'].count().reset_index()
JNorth_AFirst_Site_dt_df = pd.DataFrame(JNorth_AFirst_Site_dt_df)

# %%
JNorth_AFirst_Site_dt_df
# Out:
#      month  year                        species   lat_range  sighting_date
# 0        1  1998  Monarch Adult (FIRST sighted)   25+_TO_30              3
# 1        1  1999  Monarch Adult (FIRST sighted)   25+_TO_30              2
# 2        1  1999  Monarch Adult (FIRST sighted)   30+_TO_35              1
# 3        1  1999  Monarch Adult (FIRST sighted)   35+_TO_40              2
# 4        1  2000  Monarch Adult (FIRST sighted)   25+_TO_30              6
# ..     ...   ...                            ...         ...            ...
# 919     12  2009  Monarch Adult (FIRST sighted)   35+_TO_40              1
# 920     12  2014  Monarch Adult (FIRST sighted)   30+_TO_35              1
# 921     12  2015  Monarch Adult (FIRST sighted)   25+_TO_30              1
# 922     12  2018  Monarch Adult (FIRST sighted)  20_OR_LESS              1
# 923     12  2020  Monarch Adult (FIRST sighted)   30+_TO_35              1
#
# [924 rows x 5 columns]

# %%
JNorth_AFirst_Site_dt_df.rename(columns={'sighting_date': 'adult_first_sight_dates'}, inplace=True)
JNorth_AFirst_Site_dt_df
# Out:
#      month  year                        species   lat_range  \
# 0        1  1998  Monarch Adult (FIRST sighted)   25+_TO_30
# 1        1  1999  Monarch Adult (FIRST sighted)   25+_TO_30
# 2        1  1999  Monarch Adult (FIRST sighted)   30+_TO_35
# 3        1  1999  Monarch Adult (FIRST sighted)   35+_TO_40
# 4        1  2000  Monarch Adult (FIRST sighted)   25+_TO_30
# ..     ...   ...                            ...         ...
# 919     12  2009  Monarch Adult (FIRST sighted)   35+_TO_40
# 920     12  2014  Monarch Adult (FIRST sighted)   30+_TO_35
# 921     12  2015  Monarch Adult (FIRST sighted)   25+_TO_30
# 922     12  2018  Monarch Adult (FIRST sighted)  20_OR_LESS
# 923     12  2020  Monarch Adult (FIRST sighted)   30+_TO_35
#
#      adult_first_sight_dates
# 0                          3
# 1                          2
# 2                          1
# 3                          2
# 4                          6
# ..                       ...
# 919                        1
# ...

# %%
JNorth1996_2020_afirstsite_d_dates = JNorth_AFirst_Site_df.groupby(['month','year','species', 'lat_range'])['sighting_date'].nunique().reset_index()
JNorth1996_2020_afirstsite_d_dates = pd.DataFrame(JNorth1996_2020_afirstsite_d_dates)
JNorth1996_2020_afirstsite_d_dates
# Out:
#      month  year                        species   lat_range  sighting_date
# 0        1  1998  Monarch Adult (FIRST sighted)   25+_TO_30              3
# 1        1  1999  Monarch Adult (FIRST sighted)   25+_TO_30              2
# 2        1  1999  Monarch Adult (FIRST sighted)   30+_TO_35              1
# 3        1  1999  Monarch Adult (FIRST sighted)   35+_TO_40              2
# 4        1  2000  Monarch Adult (FIRST sighted)   25+_TO_30              5
# ..     ...   ...                            ...         ...            ...
# 919     12  2009  Monarch Adult (FIRST sighted)   35+_TO_40              1
# 920     12  2014  Monarch Adult (FIRST sighted)   30+_TO_35              1
# 921     12  2015  Monarch Adult (FIRST sighted)   25+_TO_30              1
# 922     12  2018  Monarch Adult (FIRST sighted)  20_OR_LESS              1
# 923     12  2020  Monarch Adult (FIRST sighted)   30+_TO_35              1
#
# [924 rows x 5 columns]

# %%
JNorth1996_2020_afirstsite_d_dates.rename(columns={'sighting_date': 'adult_first_sight_distinct_dates'}, inplace=True)
JNorth1996_2020_afirstsite_d_dates
# Out:
#      month  year                        species   lat_range  \
# 0        1  1998  Monarch Adult (FIRST sighted)   25+_TO_30
# 1        1  1999  Monarch Adult (FIRST sighted)   25+_TO_30
# 2        1  1999  Monarch Adult (FIRST sighted)   30+_TO_35
# 3        1  1999  Monarch Adult (FIRST sighted)   35+_TO_40
# 4        1  2000  Monarch Adult (FIRST sighted)   25+_TO_30
# ..     ...   ...                            ...         ...
# 919     12  2009  Monarch Adult (FIRST sighted)   35+_TO_40
# 920     12  2014  Monarch Adult (FIRST sighted)   30+_TO_35
# 921     12  2015  Monarch Adult (FIRST sighted)   25+_TO_30
# 922     12  2018  Monarch Adult (FIRST sighted)  20_OR_LESS
# 923     12  2020  Monarch Adult (FIRST sighted)   30+_TO_35
#
#      adult_first_sight_distinct_dates
# 0                                   3
# 1                                   2
# 2                                   1
# 3                                   2
# 4                                   5
# ...

# %%
JNorth1996_2020_afirstsite_species =JNorth_AFirst_Site_df.groupby(['month','year','species', 'lat_range'])['number'].sum().reset_index()
JNorth1996_2020_afirstsite_species
# Out:
#      month  year                        species   lat_range  number
# 0        1  1998  Monarch Adult (FIRST sighted)   25+_TO_30       3
# 1        1  1999  Monarch Adult (FIRST sighted)   25+_TO_30       2
# 2        1  1999  Monarch Adult (FIRST sighted)   30+_TO_35       1
# 3        1  1999  Monarch Adult (FIRST sighted)   35+_TO_40       2
# 4        1  2000  Monarch Adult (FIRST sighted)   25+_TO_30       6
# ..     ...   ...                            ...         ...     ...
# 919     12  2009  Monarch Adult (FIRST sighted)   35+_TO_40       1
# 920     12  2014  Monarch Adult (FIRST sighted)   30+_TO_35       1
# 921     12  2015  Monarch Adult (FIRST sighted)   25+_TO_30       2
# 922     12  2018  Monarch Adult (FIRST sighted)  20_OR_LESS       5
# 923     12  2020  Monarch Adult (FIRST sighted)   30+_TO_35       2
#
# [924 rows x 5 columns]

# %%
JNorth_AFirst_Site_dt_df['adult_first_sight_number']= JNorth1996_2020_afirstsite_species['number']
JNorth_AFirst_Site_dt_df['adult_first_sight_distinct_dates']= JNorth1996_2020_afirstsite_d_dates['adult_first_sight_distinct_dates']
JNorth_AFirst_Site_dt_df
# Out:
#      month  year                        species   lat_range  \
# 0        1  1998  Monarch Adult (FIRST sighted)   25+_TO_30
# 1        1  1999  Monarch Adult (FIRST sighted)   25+_TO_30
# 2        1  1999  Monarch Adult (FIRST sighted)   30+_TO_35
# 3        1  1999  Monarch Adult (FIRST sighted)   35+_TO_40
# 4        1  2000  Monarch Adult (FIRST sighted)   25+_TO_30
# ..     ...   ...                            ...         ...
# 919     12  2009  Monarch Adult (FIRST sighted)   35+_TO_40
# 920     12  2014  Monarch Adult (FIRST sighted)   30+_TO_35
# 921     12  2015  Monarch Adult (FIRST sighted)   25+_TO_30
# 922     12  2018  Monarch Adult (FIRST sighted)  20_OR_LESS
# 923     12  2020  Monarch Adult (FIRST sighted)   30+_TO_35
#
#      adult_first_sight_dates  adult_first_sight_number  \
# 0                          3                         3
# 1                          2                         2
# 2                          1                         1
# ...

# %%
JNorth_AFirst_Site_dt_df.drop(['species'], axis=1, inplace=True)
JNorth_AFirst_Site_dt_df
# Out:
#      month  year   lat_range  adult_first_sight_dates  \
# 0        1  1998   25+_TO_30                        3
# 1        1  1999   25+_TO_30                        2
# 2        1  1999   30+_TO_35                        1
# 3        1  1999   35+_TO_40                        2
# 4        1  2000   25+_TO_30                        6
# ..     ...   ...         ...                      ...
# 919     12  2009   35+_TO_40                        1
# 920     12  2014   30+_TO_35                        1
# 921     12  2015   25+_TO_30                        1
# 922     12  2018  20_OR_LESS                        1
# 923     12  2020   30+_TO_35                        1
#
#      adult_first_sight_number  adult_first_sight_distinct_dates
# 0                           3                                 3
# 1                           2                                 2
# 2                           1                                 1
# ...

# %%
JNorth_AFirst_Site_dt_df.shape
# Out:
# (924, 6)

# %%
JNorth_AFirst_Site_dt_df.to_csv('JNorth_Adult_First_Sighting_Summary_Pivot.csv', header=True, mode='w', index=False)

# %% [markdown]
# # Monarch Egg (FIRST sighted)

# %%
# filtering by type of observation (Monarch Egg First Sighted)
JNorth_EFirst_Site_df = JNorth1996_2020_df[JNorth1996_2020_df['species']=='Monarch Egg (FIRST sighted)']
JNorth_EFirst_Site_df.head()
# Out:
#       sighting_date                      species  number   lat_range  \
# 20173    2007-01-01  Monarch Egg (FIRST sighted)       1  20_OR_LESS
# 46244    2012-03-17  Monarch Egg (FIRST sighted)       1   20+_TO_25
# 61681    2014-03-22  Monarch Egg (FIRST sighted)       1   20+_TO_25
# 61682    2014-03-22  Monarch Egg (FIRST sighted)       1   20+_TO_25
# 61685    2014-03-21  Monarch Egg (FIRST sighted)       1   20+_TO_25
#
#                  site  year  month
# 20173  19.62--100.285  2007      1
# 46244  21.134--99.459  2012      3
# 61681  23.733--99.133  2014      3
# 61682   23.866--99.24  2014      3
# 61685  22.992--99.144  2014      3

# %%
JNorth_EFirst_Site_dt_df = JNorth_EFirst_Site_df.groupby(['month','year','species', 'lat_range'])['sighting_date'].count().reset_index()
JNorth_EFirst_Site_dt_df = pd.DataFrame(JNorth_EFirst_Site_dt_df)

# %%
JNorth_EFirst_Site_dt_df
# Out:
#      month  year                      species  lat_range  sighting_date
# 0        1  1998  Monarch Egg (FIRST sighted)  25+_TO_30              1
# 1        1  2000  Monarch Egg (FIRST sighted)  25+_TO_30              2
# 2        1  2001  Monarch Egg (FIRST sighted)  25+_TO_30              1
# 3        1  2003  Monarch Egg (FIRST sighted)  30+_TO_35              1
# 4        1  2005  Monarch Egg (FIRST sighted)  25+_TO_30              1
# ..     ...   ...                          ...        ...            ...
# 436     10  2003  Monarch Egg (FIRST sighted)  35+_TO_40              1
# 437     12  2004  Monarch Egg (FIRST sighted)  25+_TO_30              1
# 438     12  2005  Monarch Egg (FIRST sighted)  25+_TO_30              1
# 439     12  2014  Monarch Egg (FIRST sighted)  25+_TO_30              1
# 440     12  2020  Monarch Egg (FIRST sighted)  30+_TO_35              2
#
# [441 rows x 5 columns]

# %%
JNorth_EFirst_Site_dt_df.rename(columns={'sighting_date': 'egg_first_sight_dates'}, inplace=True)
JNorth_EFirst_Site_dt_df
# Out:
#      month  year                      species  lat_range  \
# 0        1  1998  Monarch Egg (FIRST sighted)  25+_TO_30
# 1        1  2000  Monarch Egg (FIRST sighted)  25+_TO_30
# 2        1  2001  Monarch Egg (FIRST sighted)  25+_TO_30
# 3        1  2003  Monarch Egg (FIRST sighted)  30+_TO_35
# 4        1  2005  Monarch Egg (FIRST sighted)  25+_TO_30
# ..     ...   ...                          ...        ...
# 436     10  2003  Monarch Egg (FIRST sighted)  35+_TO_40
# 437     12  2004  Monarch Egg (FIRST sighted)  25+_TO_30
# 438     12  2005  Monarch Egg (FIRST sighted)  25+_TO_30
# 439     12  2014  Monarch Egg (FIRST sighted)  25+_TO_30
# 440     12  2020  Monarch Egg (FIRST sighted)  30+_TO_35
#
#      egg_first_sight_dates
# 0                        1
# 1                        2
# 2                        1
# 3                        1
# 4                        1
# ..                     ...
# 436                      1
# 437                      1
# ...

# %%
JNorth1996_2020_efirstsite_d_dates = JNorth_EFirst_Site_df.groupby(['month','year','species', 'lat_range'])['sighting_date'].nunique().reset_index()
JNorth1996_2020_efirstsite_d_dates = pd.DataFrame(JNorth1996_2020_efirstsite_d_dates)
JNorth1996_2020_efirstsite_d_dates
# Out:
#      month  year                      species  lat_range  sighting_date
# 0        1  1998  Monarch Egg (FIRST sighted)  25+_TO_30              1
# 1        1  2000  Monarch Egg (FIRST sighted)  25+_TO_30              2
# 2        1  2001  Monarch Egg (FIRST sighted)  25+_TO_30              1
# 3        1  2003  Monarch Egg (FIRST sighted)  30+_TO_35              1
# 4        1  2005  Monarch Egg (FIRST sighted)  25+_TO_30              1
# ..     ...   ...                          ...        ...            ...
# 436     10  2003  Monarch Egg (FIRST sighted)  35+_TO_40              1
# 437     12  2004  Monarch Egg (FIRST sighted)  25+_TO_30              1
# 438     12  2005  Monarch Egg (FIRST sighted)  25+_TO_30              1
# 439     12  2014  Monarch Egg (FIRST sighted)  25+_TO_30              1
# 440     12  2020  Monarch Egg (FIRST sighted)  30+_TO_35              2
#
# [441 rows x 5 columns]

# %%
JNorth1996_2020_efirstsite_d_dates.rename(columns={'sighting_date': 'egg_first_sight_distinct_dates'}, inplace=True)
JNorth1996_2020_efirstsite_d_dates
# Out:
#      month  year                      species  lat_range  \
# 0        1  1998  Monarch Egg (FIRST sighted)  25+_TO_30
# 1        1  2000  Monarch Egg (FIRST sighted)  25+_TO_30
# 2        1  2001  Monarch Egg (FIRST sighted)  25+_TO_30
# 3        1  2003  Monarch Egg (FIRST sighted)  30+_TO_35
# 4        1  2005  Monarch Egg (FIRST sighted)  25+_TO_30
# ..     ...   ...                          ...        ...
# 436     10  2003  Monarch Egg (FIRST sighted)  35+_TO_40
# 437     12  2004  Monarch Egg (FIRST sighted)  25+_TO_30
# 438     12  2005  Monarch Egg (FIRST sighted)  25+_TO_30
# 439     12  2014  Monarch Egg (FIRST sighted)  25+_TO_30
# 440     12  2020  Monarch Egg (FIRST sighted)  30+_TO_35
#
#      egg_first_sight_distinct_dates
# 0                                 1
# 1                                 2
# 2                                 1
# 3                                 1
# 4                                 1
# ..                              ...
# ...

# %%
JNorth1996_2020_efirstsite_species =JNorth_EFirst_Site_df.groupby(['month','year','species', 'lat_range'])['number'].sum().reset_index()
JNorth1996_2020_efirstsite_species
# Out:
#      month  year                      species  lat_range  number
# 0        1  1998  Monarch Egg (FIRST sighted)  25+_TO_30       1
# 1        1  2000  Monarch Egg (FIRST sighted)  25+_TO_30       2
# 2        1  2001  Monarch Egg (FIRST sighted)  25+_TO_30       1
# 3        1  2003  Monarch Egg (FIRST sighted)  30+_TO_35       1
# 4        1  2005  Monarch Egg (FIRST sighted)  25+_TO_30       1
# ..     ...   ...                          ...        ...     ...
# 436     10  2003  Monarch Egg (FIRST sighted)  35+_TO_40       1
# 437     12  2004  Monarch Egg (FIRST sighted)  25+_TO_30       1
# 438     12  2005  Monarch Egg (FIRST sighted)  25+_TO_30       1
# 439     12  2014  Monarch Egg (FIRST sighted)  25+_TO_30       1
# 440     12  2020  Monarch Egg (FIRST sighted)  30+_TO_35      16
#
# [441 rows x 5 columns]

# %%
JNorth_EFirst_Site_dt_df['egg_first_sight_number']= JNorth1996_2020_efirstsite_species['number']
JNorth_EFirst_Site_dt_df['egg_first_sight_distinct_dates']= JNorth1996_2020_efirstsite_d_dates['egg_first_sight_distinct_dates']
JNorth_EFirst_Site_dt_df
# Out:
#      month  year                      species  lat_range  \
# 0        1  1998  Monarch Egg (FIRST sighted)  25+_TO_30
# 1        1  2000  Monarch Egg (FIRST sighted)  25+_TO_30
# 2        1  2001  Monarch Egg (FIRST sighted)  25+_TO_30
# 3        1  2003  Monarch Egg (FIRST sighted)  30+_TO_35
# 4        1  2005  Monarch Egg (FIRST sighted)  25+_TO_30
# ..     ...   ...                          ...        ...
# 436     10  2003  Monarch Egg (FIRST sighted)  35+_TO_40
# 437     12  2004  Monarch Egg (FIRST sighted)  25+_TO_30
# 438     12  2005  Monarch Egg (FIRST sighted)  25+_TO_30
# 439     12  2014  Monarch Egg (FIRST sighted)  25+_TO_30
# 440     12  2020  Monarch Egg (FIRST sighted)  30+_TO_35
#
#      egg_first_sight_dates  egg_first_sight_number  \
# 0                        1                       1
# 1                        2                       2
# 2                        1                       1
# 3                        1                       1
# ...

# %%
JNorth_EFirst_Site_dt_df.drop(['species'], axis=1, inplace=True)
JNorth_EFirst_Site_dt_df
# Out:
#      month  year  lat_range  egg_first_sight_dates  egg_first_sight_number  \
# 0        1  1998  25+_TO_30                      1                       1
# 1        1  2000  25+_TO_30                      2                       2
# 2        1  2001  25+_TO_30                      1                       1
# 3        1  2003  30+_TO_35                      1                       1
# 4        1  2005  25+_TO_30                      1                       1
# ..     ...   ...        ...                    ...                     ...
# 436     10  2003  35+_TO_40                      1                       1
# 437     12  2004  25+_TO_30                      1                       1
# 438     12  2005  25+_TO_30                      1                       1
# 439     12  2014  25+_TO_30                      1                       1
# 440     12  2020  30+_TO_35                      2                      16
#
#      egg_first_sight_distinct_dates
# ...

# %%
JNorth_EFirst_Site_dt_df.shape
# Out:
# (441, 6)

# %%
JNorth_EFirst_Site_dt_df.to_csv('JNorth_Egg_First_Sighting_Summary_Pivot.csv', header=True, mode='w', index=False)

# %% [markdown]
# # Monarch Larva (FIRST sighted) Pivot

# %%
# filtering by type of observation (Monarch Larva First Sighted)
JNorth_LFirst_Site_df = JNorth1996_2020_df[JNorth1996_2020_df['species']=='Monarch Larva (FIRST sighted)']
JNorth_LFirst_Site_df.head()
# Out:
#        sighting_date                        species  number   lat_range  \
# 20172     2007-01-01  Monarch Larva (FIRST sighted)       1  20_OR_LESS
# 92915     2016-04-11  Monarch Larva (FIRST sighted)       1  20_OR_LESS
# 144172    2018-03-19  Monarch Larva (FIRST sighted)       1  20_OR_LESS
# 29023     2009-07-28  Monarch Larva (FIRST sighted)       1   20+_TO_25
# 29036     2009-07-28  Monarch Larva (FIRST sighted)       1   20+_TO_25
#
#                   site  year  month
# 20172   19.62--100.285  2007      1
# 92915    19.03--98.778  2016      4
# 144172   19.03--98.778  2018      3
# 29023   20.517--99.867  2009      7
# 29036   20.517--99.867  2009      7

# %%
JNorth_LFirst_Site_dt_df = JNorth_LFirst_Site_df.groupby(['month','year','species', 'lat_range'])['sighting_date'].count().reset_index()
JNorth_LFirst_Site_dt_df = pd.DataFrame(JNorth_LFirst_Site_dt_df)

# %%
JNorth_LFirst_Site_dt_df
# Out:
#      month  year                        species  lat_range  sighting_date
# 0        1  2000  Monarch Larva (FIRST sighted)  25+_TO_30              1
# 1        1  2001  Monarch Larva (FIRST sighted)  25+_TO_30              1
# 2        1  2002  Monarch Larva (FIRST sighted)  25+_TO_30              1
# 3        1  2004  Monarch Larva (FIRST sighted)  25+_TO_30              1
# 4        1  2005  Monarch Larva (FIRST sighted)  25+_TO_30              2
# ..     ...   ...                            ...        ...            ...
# 466     12  2015  Monarch Larva (FIRST sighted)  30+_TO_35              1
# 467     12  2016  Monarch Larva (FIRST sighted)  25+_TO_30              1
# 468     12  2018  Monarch Larva (FIRST sighted)  35+_TO_40              1
# 469     12  2019  Monarch Larva (FIRST sighted)  30+_TO_35              1
# 470     12  2020  Monarch Larva (FIRST sighted)  30+_TO_35              1
#
# [471 rows x 5 columns]

# %%
JNorth_LFirst_Site_dt_df.rename(columns={'sighting_date': 'larva_first_sight_dates'}, inplace=True)
JNorth_LFirst_Site_dt_df
# Out:
#      month  year                        species  lat_range  \
# 0        1  2000  Monarch Larva (FIRST sighted)  25+_TO_30
# 1        1  2001  Monarch Larva (FIRST sighted)  25+_TO_30
# 2        1  2002  Monarch Larva (FIRST sighted)  25+_TO_30
# 3        1  2004  Monarch Larva (FIRST sighted)  25+_TO_30
# 4        1  2005  Monarch Larva (FIRST sighted)  25+_TO_30
# ..     ...   ...                            ...        ...
# 466     12  2015  Monarch Larva (FIRST sighted)  30+_TO_35
# 467     12  2016  Monarch Larva (FIRST sighted)  25+_TO_30
# 468     12  2018  Monarch Larva (FIRST sighted)  35+_TO_40
# 469     12  2019  Monarch Larva (FIRST sighted)  30+_TO_35
# 470     12  2020  Monarch Larva (FIRST sighted)  30+_TO_35
#
#      larva_first_sight_dates
# 0                          1
# 1                          1
# 2                          1
# 3                          1
# 4                          2
# ..                       ...
# 466                        1
# ...

# %%
JNorth1996_2020_lfirstsite_d_dates = JNorth_LFirst_Site_df.groupby(['month','year','species', 'lat_range'])['sighting_date'].nunique().reset_index()
JNorth1996_2020_lfirstsite_d_dates = pd.DataFrame(JNorth1996_2020_lfirstsite_d_dates)
JNorth1996_2020_lfirstsite_d_dates
# Out:
#      month  year                        species  lat_range  sighting_date
# 0        1  2000  Monarch Larva (FIRST sighted)  25+_TO_30              1
# 1        1  2001  Monarch Larva (FIRST sighted)  25+_TO_30              1
# 2        1  2002  Monarch Larva (FIRST sighted)  25+_TO_30              1
# 3        1  2004  Monarch Larva (FIRST sighted)  25+_TO_30              1
# 4        1  2005  Monarch Larva (FIRST sighted)  25+_TO_30              1
# ..     ...   ...                            ...        ...            ...
# 466     12  2015  Monarch Larva (FIRST sighted)  30+_TO_35              1
# 467     12  2016  Monarch Larva (FIRST sighted)  25+_TO_30              1
# 468     12  2018  Monarch Larva (FIRST sighted)  35+_TO_40              1
# 469     12  2019  Monarch Larva (FIRST sighted)  30+_TO_35              1
# 470     12  2020  Monarch Larva (FIRST sighted)  30+_TO_35              1
#
# [471 rows x 5 columns]

# %%
JNorth1996_2020_lfirstsite_d_dates.rename(columns={'sighting_date': 'larva_first_sight_distinct_dates'}, inplace=True)
JNorth1996_2020_lfirstsite_d_dates
# Out:
#      month  year                        species  lat_range  \
# 0        1  2000  Monarch Larva (FIRST sighted)  25+_TO_30
# 1        1  2001  Monarch Larva (FIRST sighted)  25+_TO_30
# 2        1  2002  Monarch Larva (FIRST sighted)  25+_TO_30
# 3        1  2004  Monarch Larva (FIRST sighted)  25+_TO_30
# 4        1  2005  Monarch Larva (FIRST sighted)  25+_TO_30
# ..     ...   ...                            ...        ...
# 466     12  2015  Monarch Larva (FIRST sighted)  30+_TO_35
# 467     12  2016  Monarch Larva (FIRST sighted)  25+_TO_30
# 468     12  2018  Monarch Larva (FIRST sighted)  35+_TO_40
# 469     12  2019  Monarch Larva (FIRST sighted)  30+_TO_35
# 470     12  2020  Monarch Larva (FIRST sighted)  30+_TO_35
#
#      larva_first_sight_distinct_dates
# 0                                   1
# 1                                   1
# 2                                   1
# 3                                   1
# 4                                   1
# ...

# %%
JNorth1996_2020_lfirstsite_species =JNorth_LFirst_Site_df.groupby(['month','year','species', 'lat_range'])['number'].sum().reset_index()
JNorth1996_2020_lfirstsite_species
# Out:
#      month  year                        species  lat_range  number
# 0        1  2000  Monarch Larva (FIRST sighted)  25+_TO_30       1
# 1        1  2001  Monarch Larva (FIRST sighted)  25+_TO_30       1
# 2        1  2002  Monarch Larva (FIRST sighted)  25+_TO_30       1
# 3        1  2004  Monarch Larva (FIRST sighted)  25+_TO_30       1
# 4        1  2005  Monarch Larva (FIRST sighted)  25+_TO_30       2
# ..     ...   ...                            ...        ...     ...
# 466     12  2015  Monarch Larva (FIRST sighted)  30+_TO_35      15
# 467     12  2016  Monarch Larva (FIRST sighted)  25+_TO_30       1
# 468     12  2018  Monarch Larva (FIRST sighted)  35+_TO_40      10
# 469     12  2019  Monarch Larva (FIRST sighted)  30+_TO_35       4
# 470     12  2020  Monarch Larva (FIRST sighted)  30+_TO_35       1
#
# [471 rows x 5 columns]

# %%
JNorth_LFirst_Site_dt_df['larva_first_sight_number']= JNorth1996_2020_lfirstsite_species['number']
JNorth_LFirst_Site_dt_df['larva_first_sight_distinct_dates']= JNorth1996_2020_lfirstsite_d_dates['larva_first_sight_distinct_dates']
JNorth_LFirst_Site_dt_df
# Out:
#      month  year                        species  lat_range  \
# 0        1  2000  Monarch Larva (FIRST sighted)  25+_TO_30
# 1        1  2001  Monarch Larva (FIRST sighted)  25+_TO_30
# 2        1  2002  Monarch Larva (FIRST sighted)  25+_TO_30
# 3        1  2004  Monarch Larva (FIRST sighted)  25+_TO_30
# 4        1  2005  Monarch Larva (FIRST sighted)  25+_TO_30
# ..     ...   ...                            ...        ...
# 466     12  2015  Monarch Larva (FIRST sighted)  30+_TO_35
# 467     12  2016  Monarch Larva (FIRST sighted)  25+_TO_30
# 468     12  2018  Monarch Larva (FIRST sighted)  35+_TO_40
# 469     12  2019  Monarch Larva (FIRST sighted)  30+_TO_35
# 470     12  2020  Monarch Larva (FIRST sighted)  30+_TO_35
#
#      larva_first_sight_dates  larva_first_sight_number  \
# 0                          1                         1
# 1                          1                         1
# 2                          1                         1
# ...

# %%
JNorth_LFirst_Site_dt_df.drop(['species'], axis=1, inplace=True)
JNorth_LFirst_Site_dt_df
# Out:
#      month  year  lat_range  larva_first_sight_dates  \
# 0        1  2000  25+_TO_30                        1
# 1        1  2001  25+_TO_30                        1
# 2        1  2002  25+_TO_30                        1
# 3        1  2004  25+_TO_30                        1
# 4        1  2005  25+_TO_30                        2
# ..     ...   ...        ...                      ...
# 466     12  2015  30+_TO_35                        1
# 467     12  2016  25+_TO_30                        1
# 468     12  2018  35+_TO_40                        1
# 469     12  2019  30+_TO_35                        1
# 470     12  2020  30+_TO_35                        1
#
#      larva_first_sight_number  larva_first_sight_distinct_dates
# 0                           1                                 1
# 1                           1                                 1
# 2                           1                                 1
# 3                           1                                 1
# ...

# %%
JNorth_LFirst_Site_dt_df.shape
# Out:
# (471, 6)

# %%
JNorth_LFirst_Site_dt_df.to_csv('JNorth_Larva_First_Sighting_Summary_Pivot.csv', header=True, mode='w', index=False)

# %% [markdown]
# # Monarch PEAK Migration Pivot

# %%
# filtering by type of observation (Monarch PEAK migration)
JNorth_PEAK_Site_df = JNorth1996_2020_df[JNorth1996_2020_df['species']=='Monarch PEAK Migration']
JNorth_PEAK_Site_df.head()
# Out:
#       sighting_date                 species  number   lat_range  \
# 4275     2000-10-22  Monarch PEAK Migration       1  20_OR_LESS
# 4276     2000-10-18  Monarch PEAK Migration       1  20_OR_LESS
# 12291    2004-08-01  Monarch PEAK Migration       1  20_OR_LESS
# 14551    2005-10-28  Monarch PEAK Migration       1  20_OR_LESS
# 16285    2005-11-03  Monarch PEAK Migration       1  20_OR_LESS
#
#                  site  year  month
# 4275       19.5--99.0  2000     10
# 4276   19.62--100.285  2000     10
# 12291  19.62--100.285  2004      8
# 14551  19.62--100.285  2005     10
# 16285    19.62--100.3  2005     11

# %%
JNorth_PEAK_Site_dt_df = JNorth_PEAK_Site_df.groupby(['month','year','species', 'lat_range'])['sighting_date'].count().reset_index()
JNorth_PEAK_Site_dt_df = pd.DataFrame(JNorth_PEAK_Site_dt_df)

# %%
JNorth_PEAK_Site_dt_df
# Out:
#      month  year                 species       lat_range  sighting_date
# 0        3  2019  Monarch PEAK Migration       30+_TO_35              4
# 1        4  2009  Monarch PEAK Migration       4O+_TO_45              1
# 2        6  2010  Monarch PEAK Migration       35+_TO_40              1
# 3        7  2006  Monarch PEAK Migration  5O+_OR_GREATER              1
# 4        7  2010  Monarch PEAK Migration       35+_TO_40              1
# ..     ...   ...                     ...             ...            ...
# 300     11  2020  Monarch PEAK Migration       4O+_TO_45              1
# 301     12  2000  Monarch PEAK Migration       25+_TO_30              1
# 302     12  2006  Monarch PEAK Migration      20_OR_LESS              1
# 303     12  2007  Monarch PEAK Migration      20_OR_LESS              1
# 304     12  2010  Monarch PEAK Migration       35+_TO_40              1
#
# [305 rows x 5 columns]

# %%
JNorth_PEAK_Site_dt_df.rename(columns={'sighting_date': 'peak_migration_dates'}, inplace=True)
JNorth_PEAK_Site_dt_df
# Out:
#      month  year                 species       lat_range  peak_migration_dates
# 0        3  2019  Monarch PEAK Migration       30+_TO_35                     4
# 1        4  2009  Monarch PEAK Migration       4O+_TO_45                     1
# 2        6  2010  Monarch PEAK Migration       35+_TO_40                     1
# 3        7  2006  Monarch PEAK Migration  5O+_OR_GREATER                     1
# 4        7  2010  Monarch PEAK Migration       35+_TO_40                     1
# ..     ...   ...                     ...             ...                   ...
# 300     11  2020  Monarch PEAK Migration       4O+_TO_45                     1
# 301     12  2000  Monarch PEAK Migration       25+_TO_30                     1
# 302     12  2006  Monarch PEAK Migration      20_OR_LESS                     1
# 303     12  2007  Monarch PEAK Migration      20_OR_LESS                     1
# 304     12  2010  Monarch PEAK Migration       35+_TO_40                     1
#
# [305 rows x 5 columns]

# %%
JNorth1996_2020_PEAKsite_d_dates = JNorth_PEAK_Site_df.groupby(['month','year','species', 'lat_range'])['sighting_date'].nunique().reset_index()
JNorth1996_2020_PEAKtsite_d_dates = pd.DataFrame(JNorth1996_2020_PEAKsite_d_dates)
JNorth1996_2020_PEAKsite_d_dates
# Out:
#      month  year                 species       lat_range  sighting_date
# 0        3  2019  Monarch PEAK Migration       30+_TO_35              1
# 1        4  2009  Monarch PEAK Migration       4O+_TO_45              1
# 2        6  2010  Monarch PEAK Migration       35+_TO_40              1
# 3        7  2006  Monarch PEAK Migration  5O+_OR_GREATER              1
# 4        7  2010  Monarch PEAK Migration       35+_TO_40              1
# ..     ...   ...                     ...             ...            ...
# 300     11  2020  Monarch PEAK Migration       4O+_TO_45              1
# 301     12  2000  Monarch PEAK Migration       25+_TO_30              1
# 302     12  2006  Monarch PEAK Migration      20_OR_LESS              1
# 303     12  2007  Monarch PEAK Migration      20_OR_LESS              1
# 304     12  2010  Monarch PEAK Migration       35+_TO_40              1
#
# [305 rows x 5 columns]

# %%
JNorth1996_2020_PEAKsite_d_dates.rename(columns={'sighting_date': 'peak_migration_distinct_dates'}, inplace=True)
JNorth1996_2020_PEAKsite_d_dates
# Out:
#      month  year                 species       lat_range  \
# 0        3  2019  Monarch PEAK Migration       30+_TO_35
# 1        4  2009  Monarch PEAK Migration       4O+_TO_45
# 2        6  2010  Monarch PEAK Migration       35+_TO_40
# 3        7  2006  Monarch PEAK Migration  5O+_OR_GREATER
# 4        7  2010  Monarch PEAK Migration       35+_TO_40
# ..     ...   ...                     ...             ...
# 300     11  2020  Monarch PEAK Migration       4O+_TO_45
# 301     12  2000  Monarch PEAK Migration       25+_TO_30
# 302     12  2006  Monarch PEAK Migration      20_OR_LESS
# 303     12  2007  Monarch PEAK Migration      20_OR_LESS
# 304     12  2010  Monarch PEAK Migration       35+_TO_40
#
#      peak_migration_distinct_dates
# 0                                1
# 1                                1
# 2                                1
# 3                                1
# 4                                1
# ..                             ...
# ...

# %%
JNorth1996_2020_PEAKsite_species =JNorth_PEAK_Site_df.groupby(['month','year','species', 'lat_range'])['number'].sum().reset_index()
JNorth1996_2020_PEAKsite_species
# Out:
#      month  year                 species       lat_range  number
# 0        3  2019  Monarch PEAK Migration       30+_TO_35  100400
# 1        4  2009  Monarch PEAK Migration       4O+_TO_45       1
# 2        6  2010  Monarch PEAK Migration       35+_TO_40       6
# 3        7  2006  Monarch PEAK Migration  5O+_OR_GREATER       1
# 4        7  2010  Monarch PEAK Migration       35+_TO_40       5
# ..     ...   ...                     ...             ...     ...
# 300     11  2020  Monarch PEAK Migration       4O+_TO_45      24
# 301     12  2000  Monarch PEAK Migration       25+_TO_30       1
# 302     12  2006  Monarch PEAK Migration      20_OR_LESS       1
# 303     12  2007  Monarch PEAK Migration      20_OR_LESS       1
# 304     12  2010  Monarch PEAK Migration       35+_TO_40       1
#
# [305 rows x 5 columns]

# %%
JNorth_PEAK_Site_dt_df['peak_migration_number']= JNorth1996_2020_PEAKsite_species['number']
JNorth_PEAK_Site_dt_df['peak_migration_distinct_dates']= JNorth1996_2020_PEAKsite_d_dates['peak_migration_distinct_dates']
JNorth_PEAK_Site_dt_df
# Out:
#      month  year                 species       lat_range  \
# 0        3  2019  Monarch PEAK Migration       30+_TO_35
# 1        4  2009  Monarch PEAK Migration       4O+_TO_45
# 2        6  2010  Monarch PEAK Migration       35+_TO_40
# 3        7  2006  Monarch PEAK Migration  5O+_OR_GREATER
# 4        7  2010  Monarch PEAK Migration       35+_TO_40
# ..     ...   ...                     ...             ...
# 300     11  2020  Monarch PEAK Migration       4O+_TO_45
# 301     12  2000  Monarch PEAK Migration       25+_TO_30
# 302     12  2006  Monarch PEAK Migration      20_OR_LESS
# 303     12  2007  Monarch PEAK Migration      20_OR_LESS
# 304     12  2010  Monarch PEAK Migration       35+_TO_40
#
#      peak_migration_dates  peak_migration_number  \
# 0                       4                 100400
# 1                       1                      1
# 2                       1                      6
# 3                       1                      1
# ...

# %%
JNorth_PEAK_Site_dt_df.drop(['species'], axis=1, inplace=True)
JNorth_PEAK_Site_dt_df
# Out:
#      month  year       lat_range  peak_migration_dates  peak_migration_number  \
# 0        3  2019       30+_TO_35                     4                 100400
# 1        4  2009       4O+_TO_45                     1                      1
# 2        6  2010       35+_TO_40                     1                      6
# 3        7  2006  5O+_OR_GREATER                     1                      1
# 4        7  2010       35+_TO_40                     1                      5
# ..     ...   ...             ...                   ...                    ...
# 300     11  2020       4O+_TO_45                     1                     24
# 301     12  2000       25+_TO_30                     1                      1
# 302     12  2006      20_OR_LESS                     1                      1
# 303     12  2007      20_OR_LESS                     1                      1
# 304     12  2010       35+_TO_40                     1                      1
#
# ...

# %%
JNorth_PEAK_Site_dt_df.shape
# Out:
# (305, 6)

# %%
JNorth_PEAK_Site_dt_df.to_csv('JNorth_PEAK_Migration_Summary_Pivot.csv', header=True, mode='w', index=False)

# %% [markdown]
# # Milkweed (FIRST sighted) Pivot

# %%
# filtering by type of observation (Monarch Adult Sighted)
JNorth_MFirst_Site_df = JNorth1996_2020_df[JNorth1996_2020_df['species']=='Milkweed (FIRST sighted)']
JNorth_MFirst_Site_df.head()
# Out:
#        sighting_date                   species  number  lat_range  \
# 16447     2006-03-11  Milkweed (FIRST sighted)       1  20+_TO_25
# 20162     2007-03-01  Milkweed (FIRST sighted)       1  20+_TO_25
# 38220     2011-02-27  Milkweed (FIRST sighted)       1  20+_TO_25
# 92310     2016-03-10  Milkweed (FIRST sighted)       1  20+_TO_25
# 143564    2018-03-03  Milkweed (FIRST sighted)       1  20+_TO_25
#
#                   site  year  month
# 16447   20.517--99.867  2006      3
# 20162   20.517--99.867  2007      3
# 38220   20.517--99.867  2011      2
# 92310   23.761--99.158  2016      3
# 143564    24.1--99.821  2018      3

# %%
JNorth_MFirst_Site_dt_df = JNorth_MFirst_Site_df.groupby(['month','year','species', 'lat_range'])['sighting_date'].count().reset_index()
JNorth_MFirst_Site_dt_df = pd.DataFrame(JNorth_MFirst_Site_dt_df)

# %%
JNorth_MFirst_Site_dt_df
# Out:
#      month  year                   species  lat_range  sighting_date
# 0        1  2002  Milkweed (FIRST sighted)  25+_TO_30              2
# 1        1  2004  Milkweed (FIRST sighted)  25+_TO_30              1
# 2        1  2006  Milkweed (FIRST sighted)  30+_TO_35              1
# 3        1  2007  Milkweed (FIRST sighted)  25+_TO_30              1
# 4        1  2007  Milkweed (FIRST sighted)  30+_TO_35              1
# ..     ...   ...                       ...        ...            ...
# 351      9  2007  Milkweed (FIRST sighted)  25+_TO_30              1
# 352     12  2000  Milkweed (FIRST sighted)  25+_TO_30              1
# 353     12  2006  Milkweed (FIRST sighted)  30+_TO_35              1
# 354     12  2007  Milkweed (FIRST sighted)  25+_TO_30              1
# 355     12  2019  Milkweed (FIRST sighted)  25+_TO_30              1
#
# [356 rows x 5 columns]

# %%
JNorth_MFirst_Site_dt_df.rename(columns={'sighting_date': 'milkweed_first_sight_dates'}, inplace=True)
JNorth_MFirst_Site_dt_df
# Out:
#      month  year                   species  lat_range  \
# 0        1  2002  Milkweed (FIRST sighted)  25+_TO_30
# 1        1  2004  Milkweed (FIRST sighted)  25+_TO_30
# 2        1  2006  Milkweed (FIRST sighted)  30+_TO_35
# 3        1  2007  Milkweed (FIRST sighted)  25+_TO_30
# 4        1  2007  Milkweed (FIRST sighted)  30+_TO_35
# ..     ...   ...                       ...        ...
# 351      9  2007  Milkweed (FIRST sighted)  25+_TO_30
# 352     12  2000  Milkweed (FIRST sighted)  25+_TO_30
# 353     12  2006  Milkweed (FIRST sighted)  30+_TO_35
# 354     12  2007  Milkweed (FIRST sighted)  25+_TO_30
# 355     12  2019  Milkweed (FIRST sighted)  25+_TO_30
#
#      milkweed_first_sight_dates
# 0                             2
# 1                             1
# 2                             1
# 3                             1
# 4                             1
# ..                          ...
# 351                           1
# 352                           1
# ...

# %%
JNorth1996_2020_MFirstsite_d_dates = JNorth_MFirst_Site_df.groupby(['month','year','species', 'lat_range'])['sighting_date'].nunique().reset_index()
JNorth1996_2020_MFirsttsite_d_dates = pd.DataFrame(JNorth1996_2020_MFirstsite_d_dates)
JNorth1996_2020_MFirstsite_d_dates
# Out:
#      month  year                   species  lat_range  sighting_date
# 0        1  2002  Milkweed (FIRST sighted)  25+_TO_30              1
# 1        1  2004  Milkweed (FIRST sighted)  25+_TO_30              1
# 2        1  2006  Milkweed (FIRST sighted)  30+_TO_35              1
# 3        1  2007  Milkweed (FIRST sighted)  25+_TO_30              1
# 4        1  2007  Milkweed (FIRST sighted)  30+_TO_35              1
# ..     ...   ...                       ...        ...            ...
# 351      9  2007  Milkweed (FIRST sighted)  25+_TO_30              1
# 352     12  2000  Milkweed (FIRST sighted)  25+_TO_30              1
# 353     12  2006  Milkweed (FIRST sighted)  30+_TO_35              1
# 354     12  2007  Milkweed (FIRST sighted)  25+_TO_30              1
# 355     12  2019  Milkweed (FIRST sighted)  25+_TO_30              1
#
# [356 rows x 5 columns]

# %%
JNorth1996_2020_MFirstsite_d_dates.rename(columns={'sighting_date': 'milkweed_first_sight_distinct_dates'}, inplace=True)
JNorth1996_2020_MFirstsite_d_dates
# Out:
#      month  year                   species  lat_range  \
# 0        1  2002  Milkweed (FIRST sighted)  25+_TO_30
# 1        1  2004  Milkweed (FIRST sighted)  25+_TO_30
# 2        1  2006  Milkweed (FIRST sighted)  30+_TO_35
# 3        1  2007  Milkweed (FIRST sighted)  25+_TO_30
# 4        1  2007  Milkweed (FIRST sighted)  30+_TO_35
# ..     ...   ...                       ...        ...
# 351      9  2007  Milkweed (FIRST sighted)  25+_TO_30
# 352     12  2000  Milkweed (FIRST sighted)  25+_TO_30
# 353     12  2006  Milkweed (FIRST sighted)  30+_TO_35
# 354     12  2007  Milkweed (FIRST sighted)  25+_TO_30
# 355     12  2019  Milkweed (FIRST sighted)  25+_TO_30
#
#      milkweed_first_sight_distinct_dates
# 0                                      1
# 1                                      1
# 2                                      1
# 3                                      1
# 4                                      1
# ..                                   ...
# ...

# %%
JNorth1996_2020_MFirstsite_species =JNorth_MFirst_Site_df.groupby(['month','year','species', 'lat_range'])['number'].sum().reset_index()
JNorth1996_2020_MFirstsite_species
# Out:
#      month  year                   species  lat_range  number
# 0        1  2002  Milkweed (FIRST sighted)  25+_TO_30       2
# 1        1  2004  Milkweed (FIRST sighted)  25+_TO_30       1
# 2        1  2006  Milkweed (FIRST sighted)  30+_TO_35       1
# 3        1  2007  Milkweed (FIRST sighted)  25+_TO_30       1
# 4        1  2007  Milkweed (FIRST sighted)  30+_TO_35       1
# ..     ...   ...                       ...        ...     ...
# 351      9  2007  Milkweed (FIRST sighted)  25+_TO_30       1
# 352     12  2000  Milkweed (FIRST sighted)  25+_TO_30       1
# 353     12  2006  Milkweed (FIRST sighted)  30+_TO_35       1
# 354     12  2007  Milkweed (FIRST sighted)  25+_TO_30       1
# 355     12  2019  Milkweed (FIRST sighted)  25+_TO_30       1
#
# [356 rows x 5 columns]

# %%
JNorth_MFirst_Site_dt_df['milkweed_first_sight_number']= JNorth1996_2020_MFirstsite_species['number']
JNorth_MFirst_Site_dt_df['milkweed_first_sight_distinct_dates']= JNorth1996_2020_MFirstsite_d_dates['milkweed_first_sight_distinct_dates']
JNorth_MFirst_Site_dt_df
# Out:
#      month  year                   species  lat_range  \
# 0        1  2002  Milkweed (FIRST sighted)  25+_TO_30
# 1        1  2004  Milkweed (FIRST sighted)  25+_TO_30
# 2        1  2006  Milkweed (FIRST sighted)  30+_TO_35
# 3        1  2007  Milkweed (FIRST sighted)  25+_TO_30
# 4        1  2007  Milkweed (FIRST sighted)  30+_TO_35
# ..     ...   ...                       ...        ...
# 351      9  2007  Milkweed (FIRST sighted)  25+_TO_30
# 352     12  2000  Milkweed (FIRST sighted)  25+_TO_30
# 353     12  2006  Milkweed (FIRST sighted)  30+_TO_35
# 354     12  2007  Milkweed (FIRST sighted)  25+_TO_30
# 355     12  2019  Milkweed (FIRST sighted)  25+_TO_30
#
#      milkweed_first_sight_dates  milkweed_first_sight_number  \
# 0                             2                            2
# 1                             1                            1
# 2                             1                            1
# 3                             1                            1
# ...

# %%
JNorth_MFirst_Site_dt_df.drop(['species'], axis=1, inplace=True)
JNorth_MFirst_Site_dt_df
# Out:
#      month  year  lat_range  milkweed_first_sight_dates  \
# 0        1  2002  25+_TO_30                           2
# 1        1  2004  25+_TO_30                           1
# 2        1  2006  30+_TO_35                           1
# 3        1  2007  25+_TO_30                           1
# 4        1  2007  30+_TO_35                           1
# ..     ...   ...        ...                         ...
# 351      9  2007  25+_TO_30                           1
# 352     12  2000  25+_TO_30                           1
# 353     12  2006  30+_TO_35                           1
# 354     12  2007  25+_TO_30                           1
# 355     12  2019  25+_TO_30                           1
#
#      milkweed_first_sight_number  milkweed_first_sight_distinct_dates
# 0                              2                                    1
# 1                              1                                    1
# 2                              1                                    1
# ...

# %%
JNorth_MFirst_Site_dt_df.shape
# Out:
# (356, 6)

# %%
JNorth_MFirst_Site_dt_df.to_csv('JNorth_Milkweed_First_Sighting_Summary_Pivot.csv', header=True, mode='w', index=False)

# %% [markdown]
# # Monarch Fall Roost Pivot

# %%
# filtering by type of observation (Monarch Fall Roost)
JNorth_FallRoost_Site_df = JNorth1996_2020_df[JNorth1996_2020_df['species']=='Monarch Fall Roost']
JNorth_FallRoost_Site_df.head()
# Out:
#       sighting_date             species   number   lat_range            site  \
# 12289    2004-08-01  Monarch Fall Roost        1  20_OR_LESS  19.62--100.285
# 14549    2005-10-28  Monarch Fall Roost        1  20_OR_LESS  19.62--100.285
# 17877    2006-12-26  Monarch Fall Roost        1  20_OR_LESS  19.62--100.285
# 18451    2006-09-14  Monarch Fall Roost        1  20_OR_LESS  19.62--100.285
# 21465    2007-12-26  Monarch Fall Roost  1000000  20_OR_LESS  19.62--100.285
#
#        year  month
# 12289  2004      8
# 14549  2005     10
# 17877  2006     12
# 18451  2006      9
# 21465  2007     12

# %%
JNorth_FallRoost_Site_dt_df = JNorth_FallRoost_Site_df.groupby(['month','year','species', 'lat_range'])['sighting_date'].count().reset_index()
JNorth_FallRoost_Site_dt_df = pd.DataFrame(JNorth_FallRoost_Site_dt_df)

# %%
JNorth_FallRoost_Site_dt_df
# Out:
#      month  year             species  lat_range  sighting_date
# 0        1  2004  Monarch Fall Roost  30+_TO_35              1
# 1        3  2009  Monarch Fall Roost  4O+_TO_45              1
# 2        4  2009  Monarch Fall Roost  4O+_TO_45              1
# 3        7  2019  Monarch Fall Roost  4O+_TO_45              2
# 4        8  2002  Monarch Fall Roost  45+_TO_50              2
# ..     ...   ...                 ...        ...            ...
# 275     12  2015  Monarch Fall Roost  35+_TO_40              2
# 276     12  2016  Monarch Fall Roost  20+_TO_25              1
# 277     12  2016  Monarch Fall Roost  30+_TO_35              1
# 278     12  2016  Monarch Fall Roost  35+_TO_40              1
# 279     12  2018  Monarch Fall Roost  35+_TO_40              1
#
# [280 rows x 5 columns]

# %%
JNorth_FallRoost_Site_dt_df.rename(columns={'sighting_date': 'fall_roost_dates'}, inplace=True)
JNorth_FallRoost_Site_dt_df
# Out:
#      month  year             species  lat_range  fall_roost_dates
# 0        1  2004  Monarch Fall Roost  30+_TO_35                 1
# 1        3  2009  Monarch Fall Roost  4O+_TO_45                 1
# 2        4  2009  Monarch Fall Roost  4O+_TO_45                 1
# 3        7  2019  Monarch Fall Roost  4O+_TO_45                 2
# 4        8  2002  Monarch Fall Roost  45+_TO_50                 2
# ..     ...   ...                 ...        ...               ...
# 275     12  2015  Monarch Fall Roost  35+_TO_40                 2
# 276     12  2016  Monarch Fall Roost  20+_TO_25                 1
# 277     12  2016  Monarch Fall Roost  30+_TO_35                 1
# 278     12  2016  Monarch Fall Roost  35+_TO_40                 1
# 279     12  2018  Monarch Fall Roost  35+_TO_40                 1
#
# [280 rows x 5 columns]

# %%
JNorth1996_2020_FallRoostsite_d_dates = JNorth_FallRoost_Site_df.groupby(['month','year','species', 'lat_range'])['sighting_date'].nunique().reset_index()
JNorth1996_2020_FallRoostsite_d_dates = pd.DataFrame(JNorth1996_2020_FallRoostsite_d_dates)
JNorth1996_2020_FallRoostsite_d_dates
# Out:
#      month  year             species  lat_range  sighting_date
# 0        1  2004  Monarch Fall Roost  30+_TO_35              1
# 1        3  2009  Monarch Fall Roost  4O+_TO_45              1
# 2        4  2009  Monarch Fall Roost  4O+_TO_45              1
# 3        7  2019  Monarch Fall Roost  4O+_TO_45              2
# 4        8  2002  Monarch Fall Roost  45+_TO_50              2
# ..     ...   ...                 ...        ...            ...
# 275     12  2015  Monarch Fall Roost  35+_TO_40              1
# 276     12  2016  Monarch Fall Roost  20+_TO_25              1
# 277     12  2016  Monarch Fall Roost  30+_TO_35              1
# 278     12  2016  Monarch Fall Roost  35+_TO_40              1
# 279     12  2018  Monarch Fall Roost  35+_TO_40              1
#
# [280 rows x 5 columns]

# %%
JNorth1996_2020_FallRoostsite_d_dates.rename(columns={'sighting_date': 'fall_roost_distinct_dates'}, inplace=True)
JNorth1996_2020_FallRoostsite_d_dates
# Out:
#      month  year             species  lat_range  fall_roost_distinct_dates
# 0        1  2004  Monarch Fall Roost  30+_TO_35                          1
# 1        3  2009  Monarch Fall Roost  4O+_TO_45                          1
# 2        4  2009  Monarch Fall Roost  4O+_TO_45                          1
# 3        7  2019  Monarch Fall Roost  4O+_TO_45                          2
# 4        8  2002  Monarch Fall Roost  45+_TO_50                          2
# ..     ...   ...                 ...        ...                        ...
# 275     12  2015  Monarch Fall Roost  35+_TO_40                          1
# 276     12  2016  Monarch Fall Roost  20+_TO_25                          1
# 277     12  2016  Monarch Fall Roost  30+_TO_35                          1
# 278     12  2016  Monarch Fall Roost  35+_TO_40                          1
# 279     12  2018  Monarch Fall Roost  35+_TO_40                          1
#
# [280 rows x 5 columns]

# %%
JNorth1996_2020_FallRoostsite_species =JNorth_FallRoost_Site_df.groupby(['month','year','species', 'lat_range'])['number'].sum().reset_index()
JNorth1996_2020_FallRoostsite_species
# Out:
#      month  year             species  lat_range  number
# 0        1  2004  Monarch Fall Roost  30+_TO_35       1
# 1        3  2009  Monarch Fall Roost  4O+_TO_45     125
# 2        4  2009  Monarch Fall Roost  4O+_TO_45     130
# 3        7  2019  Monarch Fall Roost  4O+_TO_45      15
# 4        8  2002  Monarch Fall Roost  45+_TO_50       2
# ..     ...   ...                 ...        ...     ...
# 275     12  2015  Monarch Fall Roost  35+_TO_40    1006
# 276     12  2016  Monarch Fall Roost  20+_TO_25    2500
# 277     12  2016  Monarch Fall Roost  30+_TO_35     100
# 278     12  2016  Monarch Fall Roost  35+_TO_40     500
# 279     12  2018  Monarch Fall Roost  35+_TO_40     110
#
# [280 rows x 5 columns]

# %%
JNorth_FallRoost_Site_dt_df['fall_roost_number']= JNorth1996_2020_FallRoostsite_species['number']
JNorth_FallRoost_Site_dt_df['fall_roost_distinct_dates']= JNorth1996_2020_FallRoostsite_d_dates['fall_roost_distinct_dates']
JNorth_FallRoost_Site_dt_df
# Out:
#      month  year             species  lat_range  fall_roost_dates  \
# 0        1  2004  Monarch Fall Roost  30+_TO_35                 1
# 1        3  2009  Monarch Fall Roost  4O+_TO_45                 1
# 2        4  2009  Monarch Fall Roost  4O+_TO_45                 1
# 3        7  2019  Monarch Fall Roost  4O+_TO_45                 2
# 4        8  2002  Monarch Fall Roost  45+_TO_50                 2
# ..     ...   ...                 ...        ...               ...
# 275     12  2015  Monarch Fall Roost  35+_TO_40                 2
# 276     12  2016  Monarch Fall Roost  20+_TO_25                 1
# 277     12  2016  Monarch Fall Roost  30+_TO_35                 1
# 278     12  2016  Monarch Fall Roost  35+_TO_40                 1
# 279     12  2018  Monarch Fall Roost  35+_TO_40                 1
#
#      fall_roost_number  fall_roost_distinct_dates
# 0                    1                          1
# 1                  125                          1
# ...

# %%
JNorth_FallRoost_Site_dt_df.drop(['species'], axis=1, inplace=True)
JNorth_FallRoost_Site_dt_df
# Out:
#      month  year  lat_range  fall_roost_dates  fall_roost_number  \
# 0        1  2004  30+_TO_35                 1                  1
# 1        3  2009  4O+_TO_45                 1                125
# 2        4  2009  4O+_TO_45                 1                130
# 3        7  2019  4O+_TO_45                 2                 15
# 4        8  2002  45+_TO_50                 2                  2
# ..     ...   ...        ...               ...                ...
# 275     12  2015  35+_TO_40                 2               1006
# 276     12  2016  20+_TO_25                 1               2500
# 277     12  2016  30+_TO_35                 1                100
# 278     12  2016  35+_TO_40                 1                500
# 279     12  2018  35+_TO_40                 1                110
#
#      fall_roost_distinct_dates
# 0                            1
# 1                            1
# 2                            1
# 3                            2
# ...

# %%
JNorth_FallRoost_Site_dt_df.shape
# Out:
# (280, 6)

# %%
JNorth_FallRoost_Site_dt_df.to_csv('JNorth_Fall_Roost_Summary_Pivot.csv', header=True, mode='w', index=False)

# %% [markdown]
# # Monarch Egg Sighted Pivot

# %%
# filtering by type of observation (Monarch Egg Sighted)
JNorth_Egg_Site_df = JNorth1996_2020_df[JNorth1996_2020_df['species']=='Monarch Egg Sighted']
JNorth_Egg_Site_df.head()
# Out:
#       sighting_date              species  number  lat_range            site  \
# 73247    2014-10-22  Monarch Egg Sighted       1  20+_TO_25  23.733--99.133
# 89637    2015-10-15  Monarch Egg Sighted       1  20+_TO_25  23.066--99.168
# 92176    2016-03-24  Monarch Egg Sighted       2  20+_TO_25  23.411--99.379
# 92687    2016-04-04  Monarch Egg Sighted      10  20+_TO_25  23.461--99.298
# 92691    2016-04-04  Monarch Egg Sighted       3  20+_TO_25  23.453--99.282
#
#        year  month
# 73247  2014     10
# 89637  2015     10
# 92176  2016      3
# 92687  2016      4
# 92691  2016      4

# %%
JNorth_Egg_Site_dt_df = JNorth_Egg_Site_df.groupby(['month','year','species', 'lat_range'])['sighting_date'].count().reset_index()
JNorth_Egg_Site_dt_df = pd.DataFrame(JNorth_Egg_Site_dt_df)

# %%
JNorth_Egg_Site_dt_df
# Out:
#      month  year              species  lat_range  sighting_date
# 0        1  2015  Monarch Egg Sighted  30+_TO_35              1
# 1        1  2016  Monarch Egg Sighted  25+_TO_30              1
# 2        1  2016  Monarch Egg Sighted  30+_TO_35              2
# 3        1  2017  Monarch Egg Sighted  20+_TO_25              1
# 4        1  2017  Monarch Egg Sighted  25+_TO_30              5
# ..     ...   ...                  ...        ...            ...
# 309     12  2018  Monarch Egg Sighted  25+_TO_30              3
# 310     12  2019  Monarch Egg Sighted  25+_TO_30              4
# 311     12  2019  Monarch Egg Sighted  30+_TO_35              1
# 312     12  2020  Monarch Egg Sighted  25+_TO_30             34
# 313     12  2020  Monarch Egg Sighted  30+_TO_35              5
#
# [314 rows x 5 columns]

# %%
JNorth_Egg_Site_dt_df.rename(columns={'sighting_date': 'egg_sight_dates'}, inplace=True)
JNorth_Egg_Site_dt_df
# Out:
#      month  year              species  lat_range  egg_sight_dates
# 0        1  2015  Monarch Egg Sighted  30+_TO_35                1
# 1        1  2016  Monarch Egg Sighted  25+_TO_30                1
# 2        1  2016  Monarch Egg Sighted  30+_TO_35                2
# 3        1  2017  Monarch Egg Sighted  20+_TO_25                1
# 4        1  2017  Monarch Egg Sighted  25+_TO_30                5
# ..     ...   ...                  ...        ...              ...
# 309     12  2018  Monarch Egg Sighted  25+_TO_30                3
# 310     12  2019  Monarch Egg Sighted  25+_TO_30                4
# 311     12  2019  Monarch Egg Sighted  30+_TO_35                1
# 312     12  2020  Monarch Egg Sighted  25+_TO_30               34
# 313     12  2020  Monarch Egg Sighted  30+_TO_35                5
#
# [314 rows x 5 columns]

# %%
JNorth1996_2020_Eggsite_d_dates = JNorth_Egg_Site_df.groupby(['month','year','species', 'lat_range'])['sighting_date'].nunique().reset_index()
JNorth1996_2020_Eggsite_d_dates = pd.DataFrame(JNorth1996_2020_Eggsite_d_dates)
JNorth1996_2020_Eggsite_d_dates
# Out:
#      month  year              species  lat_range  sighting_date
# 0        1  2015  Monarch Egg Sighted  30+_TO_35              1
# 1        1  2016  Monarch Egg Sighted  25+_TO_30              1
# 2        1  2016  Monarch Egg Sighted  30+_TO_35              2
# 3        1  2017  Monarch Egg Sighted  20+_TO_25              1
# 4        1  2017  Monarch Egg Sighted  25+_TO_30              5
# ..     ...   ...                  ...        ...            ...
# 309     12  2018  Monarch Egg Sighted  25+_TO_30              3
# 310     12  2019  Monarch Egg Sighted  25+_TO_30              4
# 311     12  2019  Monarch Egg Sighted  30+_TO_35              1
# 312     12  2020  Monarch Egg Sighted  25+_TO_30             13
# 313     12  2020  Monarch Egg Sighted  30+_TO_35              5
#
# [314 rows x 5 columns]

# %%
JNorth1996_2020_Eggsite_d_dates.rename(columns={'sighting_date': 'egg_sight_distinct_dates'}, inplace=True)
JNorth1996_2020_Eggsite_d_dates
# Out:
#      month  year              species  lat_range  egg_sight_distinct_dates
# 0        1  2015  Monarch Egg Sighted  30+_TO_35                         1
# 1        1  2016  Monarch Egg Sighted  25+_TO_30                         1
# 2        1  2016  Monarch Egg Sighted  30+_TO_35                         2
# 3        1  2017  Monarch Egg Sighted  20+_TO_25                         1
# 4        1  2017  Monarch Egg Sighted  25+_TO_30                         5
# ..     ...   ...                  ...        ...                       ...
# 309     12  2018  Monarch Egg Sighted  25+_TO_30                         3
# 310     12  2019  Monarch Egg Sighted  25+_TO_30                         4
# 311     12  2019  Monarch Egg Sighted  30+_TO_35                         1
# 312     12  2020  Monarch Egg Sighted  25+_TO_30                        13
# 313     12  2020  Monarch Egg Sighted  30+_TO_35                         5
#
# [314 rows x 5 columns]

# %%
JNorth1996_2020_Eggsite_species =JNorth_Egg_Site_df.groupby(['month','year','species', 'lat_range'])['number'].sum().reset_index()
JNorth1996_2020_Eggsite_species
# Out:
#      month  year              species  lat_range  number
# 0        1  2015  Monarch Egg Sighted  30+_TO_35      10
# 1        1  2016  Monarch Egg Sighted  25+_TO_30       1
# 2        1  2016  Monarch Egg Sighted  30+_TO_35      21
# 3        1  2017  Monarch Egg Sighted  20+_TO_25       5
# 4        1  2017  Monarch Egg Sighted  25+_TO_30      35
# ..     ...   ...                  ...        ...     ...
# 309     12  2018  Monarch Egg Sighted  25+_TO_30      25
# 310     12  2019  Monarch Egg Sighted  25+_TO_30      20
# 311     12  2019  Monarch Egg Sighted  30+_TO_35       1
# 312     12  2020  Monarch Egg Sighted  25+_TO_30     183
# 313     12  2020  Monarch Egg Sighted  30+_TO_35      17
#
# [314 rows x 5 columns]

# %%
JNorth_Egg_Site_dt_df['egg_sight_number']= JNorth1996_2020_Eggsite_species['number']
JNorth_Egg_Site_dt_df['egg_sight_distinct_dates']= JNorth1996_2020_Eggsite_d_dates['egg_sight_distinct_dates']
JNorth_Egg_Site_dt_df
# Out:
#      month  year              species  lat_range  egg_sight_dates  \
# 0        1  2015  Monarch Egg Sighted  30+_TO_35                1
# 1        1  2016  Monarch Egg Sighted  25+_TO_30                1
# 2        1  2016  Monarch Egg Sighted  30+_TO_35                2
# 3        1  2017  Monarch Egg Sighted  20+_TO_25                1
# 4        1  2017  Monarch Egg Sighted  25+_TO_30                5
# ..     ...   ...                  ...        ...              ...
# 309     12  2018  Monarch Egg Sighted  25+_TO_30                3
# 310     12  2019  Monarch Egg Sighted  25+_TO_30                4
# 311     12  2019  Monarch Egg Sighted  30+_TO_35                1
# 312     12  2020  Monarch Egg Sighted  25+_TO_30               34
# 313     12  2020  Monarch Egg Sighted  30+_TO_35                5
#
#      egg_sight_number  egg_sight_distinct_dates
# 0                  10                         1
# 1                   1                         1
# ...

# %%
JNorth_Egg_Site_dt_df.drop(['species'], axis=1, inplace=True)
JNorth_Egg_Site_dt_df
# Out:
#      month  year  lat_range  egg_sight_dates  egg_sight_number  \
# 0        1  2015  30+_TO_35                1                10
# 1        1  2016  25+_TO_30                1                 1
# 2        1  2016  30+_TO_35                2                21
# 3        1  2017  20+_TO_25                1                 5
# 4        1  2017  25+_TO_30                5                35
# ..     ...   ...        ...              ...               ...
# 309     12  2018  25+_TO_30                3                25
# 310     12  2019  25+_TO_30                4                20
# 311     12  2019  30+_TO_35                1                 1
# 312     12  2020  25+_TO_30               34               183
# 313     12  2020  30+_TO_35                5                17
#
#      egg_sight_distinct_dates
# 0                           1
# 1                           1
# 2                           2
# 3                           1
# 4                           5
# ...

# %%
JNorth_Egg_Site_dt_df.shape
# Out:
# (314, 6)

# %%
JNorth_Egg_Site_dt_df.to_csv('JNorth_Egg_Sighting_Summary_Pivot.csv', header=True, mode='w', index=False)

# %% [markdown]
# # Monarch Larva Sighted Pivot

# %%
# filtering by type of observation (Monarch Larva Sighted )
JNorth_Larva_Site_df = JNorth1996_2020_df[JNorth1996_2020_df['species']=='Monarch Larva Sighted']
JNorth_Larva_Site_df.head()
# Out:
#        sighting_date                species  number   lat_range  \
# 91082     2015-11-19  Monarch Larva Sighted      15  20_OR_LESS
# 91605     2016-02-01  Monarch Larva Sighted      10  20_OR_LESS
# 91762     2016-03-04  Monarch Larva Sighted      12  20_OR_LESS
# 115982    2017-02-16  Monarch Larva Sighted       4  20_OR_LESS
# 168351    2018-09-30  Monarch Larva Sighted       1  20_OR_LESS
#
#                    site  year  month
# 91082    18.452--66.047  2015     11
# 91605    18.333--64.733  2016      2
# 91762     18.711--79.98  2016      3
# 115982   19.364--100.29  2017      2
# 168351  19.706--101.195  2018      9

# %%
JNorth_Larva_Site_dt_df = JNorth_Larva_Site_df.groupby(['month','year','species', 'lat_range'])['sighting_date'].count().reset_index()
JNorth_Larva_Site_dt_df = pd.DataFrame(JNorth_Larva_Site_dt_df)

# %%
JNorth_Larva_Site_dt_df
# Out:
#      month  year                species  lat_range  sighting_date
# 0        1  2016  Monarch Larva Sighted  25+_TO_30             19
# 1        1  2016  Monarch Larva Sighted  30+_TO_35             15
# 2        1  2017  Monarch Larva Sighted  20+_TO_25              1
# 3        1  2017  Monarch Larva Sighted  25+_TO_30             20
# 4        1  2017  Monarch Larva Sighted  30+_TO_35             22
# ..     ...   ...                    ...        ...            ...
# 377     12  2019  Monarch Larva Sighted  35+_TO_40              1
# 378     12  2020  Monarch Larva Sighted  20+_TO_25              1
# 379     12  2020  Monarch Larva Sighted  25+_TO_30             62
# 380     12  2020  Monarch Larva Sighted  30+_TO_35             40
# 381     12  2020  Monarch Larva Sighted  35+_TO_40              1
#
# [382 rows x 5 columns]

# %%
JNorth_Larva_Site_dt_df.rename(columns={'sighting_date': 'larva_sight_dates'}, inplace=True)
JNorth_Larva_Site_dt_df
# Out:
#      month  year                species  lat_range  larva_sight_dates
# 0        1  2016  Monarch Larva Sighted  25+_TO_30                 19
# 1        1  2016  Monarch Larva Sighted  30+_TO_35                 15
# 2        1  2017  Monarch Larva Sighted  20+_TO_25                  1
# 3        1  2017  Monarch Larva Sighted  25+_TO_30                 20
# 4        1  2017  Monarch Larva Sighted  30+_TO_35                 22
# ..     ...   ...                    ...        ...                ...
# 377     12  2019  Monarch Larva Sighted  35+_TO_40                  1
# 378     12  2020  Monarch Larva Sighted  20+_TO_25                  1
# 379     12  2020  Monarch Larva Sighted  25+_TO_30                 62
# 380     12  2020  Monarch Larva Sighted  30+_TO_35                 40
# 381     12  2020  Monarch Larva Sighted  35+_TO_40                  1
#
# [382 rows x 5 columns]

# %%
JNorth1996_2020_Larvasite_d_dates = JNorth_Larva_Site_df.groupby(['month','year','species', 'lat_range'])['sighting_date'].nunique().reset_index()
JNorth1996_2020_Larvasite_d_dates = pd.DataFrame(JNorth1996_2020_Larvasite_d_dates)
JNorth1996_2020_Larvasite_d_dates
# Out:
#      month  year                species  lat_range  sighting_date
# 0        1  2016  Monarch Larva Sighted  25+_TO_30             17
# 1        1  2016  Monarch Larva Sighted  30+_TO_35              9
# 2        1  2017  Monarch Larva Sighted  20+_TO_25              1
# 3        1  2017  Monarch Larva Sighted  25+_TO_30             13
# 4        1  2017  Monarch Larva Sighted  30+_TO_35             17
# ..     ...   ...                    ...        ...            ...
# 377     12  2019  Monarch Larva Sighted  35+_TO_40              1
# 378     12  2020  Monarch Larva Sighted  20+_TO_25              1
# 379     12  2020  Monarch Larva Sighted  25+_TO_30             26
# 380     12  2020  Monarch Larva Sighted  30+_TO_35             22
# 381     12  2020  Monarch Larva Sighted  35+_TO_40              1
#
# [382 rows x 5 columns]

# %%
JNorth1996_2020_Larvasite_d_dates.rename(columns={'sighting_date': 'larva_sight_distinct_dates'}, inplace=True)
JNorth1996_2020_Larvasite_d_dates
# Out:
#      month  year                species  lat_range  larva_sight_distinct_dates
# 0        1  2016  Monarch Larva Sighted  25+_TO_30                          17
# 1        1  2016  Monarch Larva Sighted  30+_TO_35                           9
# 2        1  2017  Monarch Larva Sighted  20+_TO_25                           1
# 3        1  2017  Monarch Larva Sighted  25+_TO_30                          13
# 4        1  2017  Monarch Larva Sighted  30+_TO_35                          17
# ..     ...   ...                    ...        ...                         ...
# 377     12  2019  Monarch Larva Sighted  35+_TO_40                           1
# 378     12  2020  Monarch Larva Sighted  20+_TO_25                           1
# 379     12  2020  Monarch Larva Sighted  25+_TO_30                          26
# 380     12  2020  Monarch Larva Sighted  30+_TO_35                          22
# 381     12  2020  Monarch Larva Sighted  35+_TO_40                           1
#
# [382 rows x 5 columns]

# %%
JNorth1996_2020_Larvasite_species =JNorth_Larva_Site_df.groupby(['month','year','species', 'lat_range'])['number'].sum().reset_index()
JNorth1996_2020_Larvasite_species
# Out:
#      month  year                species  lat_range  number
# 0        1  2016  Monarch Larva Sighted  25+_TO_30     202
# 1        1  2016  Monarch Larva Sighted  30+_TO_35     109
# 2        1  2017  Monarch Larva Sighted  20+_TO_25       5
# 3        1  2017  Monarch Larva Sighted  25+_TO_30     140
# 4        1  2017  Monarch Larva Sighted  30+_TO_35     109
# ..     ...   ...                    ...        ...     ...
# 377     12  2019  Monarch Larva Sighted  35+_TO_40       1
# 378     12  2020  Monarch Larva Sighted  20+_TO_25       6
# 379     12  2020  Monarch Larva Sighted  25+_TO_30     330
# 380     12  2020  Monarch Larva Sighted  30+_TO_35     250
# 381     12  2020  Monarch Larva Sighted  35+_TO_40      21
#
# [382 rows x 5 columns]

# %%
JNorth_Larva_Site_dt_df['larva_sight_number']= JNorth1996_2020_Larvasite_species['number']
JNorth_Larva_Site_dt_df['larva_sight_distinct_dates']= JNorth1996_2020_Larvasite_d_dates['larva_sight_distinct_dates']
JNorth_Larva_Site_dt_df
# Out:
#      month  year                species  lat_range  larva_sight_dates  \
# 0        1  2016  Monarch Larva Sighted  25+_TO_30                 19
# 1        1  2016  Monarch Larva Sighted  30+_TO_35                 15
# 2        1  2017  Monarch Larva Sighted  20+_TO_25                  1
# 3        1  2017  Monarch Larva Sighted  25+_TO_30                 20
# 4        1  2017  Monarch Larva Sighted  30+_TO_35                 22
# ..     ...   ...                    ...        ...                ...
# 377     12  2019  Monarch Larva Sighted  35+_TO_40                  1
# 378     12  2020  Monarch Larva Sighted  20+_TO_25                  1
# 379     12  2020  Monarch Larva Sighted  25+_TO_30                 62
# 380     12  2020  Monarch Larva Sighted  30+_TO_35                 40
# 381     12  2020  Monarch Larva Sighted  35+_TO_40                  1
#
#      larva_sight_number  larva_sight_distinct_dates
# 0                   202                          17
# ...

# %%
JNorth_Larva_Site_dt_df.drop(['species'], axis=1, inplace=True)
JNorth_Larva_Site_dt_df
# Out:
#      month  year  lat_range  larva_sight_dates  larva_sight_number  \
# 0        1  2016  25+_TO_30                 19                 202
# 1        1  2016  30+_TO_35                 15                 109
# 2        1  2017  20+_TO_25                  1                   5
# 3        1  2017  25+_TO_30                 20                 140
# 4        1  2017  30+_TO_35                 22                 109
# ..     ...   ...        ...                ...                 ...
# 377     12  2019  35+_TO_40                  1                   1
# 378     12  2020  20+_TO_25                  1                   6
# 379     12  2020  25+_TO_30                 62                 330
# 380     12  2020  30+_TO_35                 40                 250
# 381     12  2020  35+_TO_40                  1                  21
#
#      larva_sight_distinct_dates
# 0                            17
# 1                             9
# 2                             1
# ...

# %%
JNorth_Larva_Site_dt_df.shape
# Out:
# (382, 6)

# %%
JNorth_Larva_Site_dt_df.to_csv('JNorth_Larva_Sighting_Summary_Pivot.csv', header=True, mode='w', index=False)

# %% [markdown]
#  # Monarch, Captive-Reared Pivot

# %%
# filtering by type of observation (Monarch, Captive-Reared)
JNorth_CapRear_Site_df = JNorth1996_2020_df[JNorth1996_2020_df['species']=='Monarch, Captive-Reared']
JNorth_CapRear_Site_df.head()
# Out:
#        sighting_date                  species  number  lat_range  \
# 92703     2016-04-09  Monarch, Captive-Reared       5  20+_TO_25
# 92712     2016-04-06  Monarch, Captive-Reared       1  20+_TO_25
# 116033    2017-03-01  Monarch, Captive-Reared       5  20+_TO_25
# 162414    2018-09-10  Monarch, Captive-Reared      24  20+_TO_25
# 200726    2020-01-09  Monarch, Captive-Reared       2  20+_TO_25
#
#                    site  year  month
# 92703    23.766--99.119  2016      4
# 92712    23.767--99.141  2016      4
# 116033    24.69--81.377  2017      3
# 162414   20.859--90.397  2018      9
# 200726  21.482--157.996  2020      1

# %%
JNorth_CapRear_Site_dt_df = JNorth_CapRear_Site_df.groupby(['month','year','species', 'lat_range'])['sighting_date'].count().reset_index()
JNorth_CapRear_Site_dt_df = pd.DataFrame(JNorth_CapRear_Site_dt_df)

# %%
JNorth_CapRear_Site_dt_df
# Out:
#      month  year                  species  lat_range  sighting_date
# 0        1  2016  Monarch, Captive-Reared  25+_TO_30              5
# 1        1  2016  Monarch, Captive-Reared  30+_TO_35              6
# 2        1  2017  Monarch, Captive-Reared  25+_TO_30              4
# 3        1  2017  Monarch, Captive-Reared  30+_TO_35             12
# 4        1  2017  Monarch, Captive-Reared  35+_TO_40              2
# ..     ...   ...                      ...        ...            ...
# 270     12  2019  Monarch, Captive-Reared  30+_TO_35             25
# 271     12  2019  Monarch, Captive-Reared  35+_TO_40              1
# 272     12  2020  Monarch, Captive-Reared  25+_TO_30              6
# 273     12  2020  Monarch, Captive-Reared  30+_TO_35             14
# 274     12  2020  Monarch, Captive-Reared  35+_TO_40              3
#
# [275 rows x 5 columns]

# %%
JNorth_CapRear_Site_dt_df.rename(columns={'sighting_date': 'captive_reared_dates'}, inplace=True)
JNorth_CapRear_Site_dt_df
# Out:
#      month  year                  species  lat_range  captive_reared_dates
# 0        1  2016  Monarch, Captive-Reared  25+_TO_30                     5
# 1        1  2016  Monarch, Captive-Reared  30+_TO_35                     6
# 2        1  2017  Monarch, Captive-Reared  25+_TO_30                     4
# 3        1  2017  Monarch, Captive-Reared  30+_TO_35                    12
# 4        1  2017  Monarch, Captive-Reared  35+_TO_40                     2
# ..     ...   ...                      ...        ...                   ...
# 270     12  2019  Monarch, Captive-Reared  30+_TO_35                    25
# 271     12  2019  Monarch, Captive-Reared  35+_TO_40                     1
# 272     12  2020  Monarch, Captive-Reared  25+_TO_30                     6
# 273     12  2020  Monarch, Captive-Reared  30+_TO_35                    14
# 274     12  2020  Monarch, Captive-Reared  35+_TO_40                     3
#
# [275 rows x 5 columns]

# %%
JNorth1996_2020_CapRearsite_d_dates = JNorth_CapRear_Site_df.groupby(['month','year','species', 'lat_range'])['sighting_date'].nunique().reset_index()
JNorth1996_2020_CapRearsite_d_dates = pd.DataFrame(JNorth1996_2020_CapRearsite_d_dates)
JNorth1996_2020_CapRearsite_d_dates
# Out:
#      month  year                  species  lat_range  sighting_date
# 0        1  2016  Monarch, Captive-Reared  25+_TO_30              4
# 1        1  2016  Monarch, Captive-Reared  30+_TO_35              5
# 2        1  2017  Monarch, Captive-Reared  25+_TO_30              3
# 3        1  2017  Monarch, Captive-Reared  30+_TO_35              9
# 4        1  2017  Monarch, Captive-Reared  35+_TO_40              2
# ..     ...   ...                      ...        ...            ...
# 270     12  2019  Monarch, Captive-Reared  30+_TO_35             19
# 271     12  2019  Monarch, Captive-Reared  35+_TO_40              1
# 272     12  2020  Monarch, Captive-Reared  25+_TO_30              4
# 273     12  2020  Monarch, Captive-Reared  30+_TO_35             10
# 274     12  2020  Monarch, Captive-Reared  35+_TO_40              3
#
# [275 rows x 5 columns]

# %%
JNorth1996_2020_CapRearsite_d_dates.rename(columns={'sighting_date': 'captive_reared_distinct_dates'}, inplace=True)
JNorth1996_2020_CapRearsite_d_dates
# Out:
#      month  year                  species  lat_range  \
# 0        1  2016  Monarch, Captive-Reared  25+_TO_30
# 1        1  2016  Monarch, Captive-Reared  30+_TO_35
# 2        1  2017  Monarch, Captive-Reared  25+_TO_30
# 3        1  2017  Monarch, Captive-Reared  30+_TO_35
# 4        1  2017  Monarch, Captive-Reared  35+_TO_40
# ..     ...   ...                      ...        ...
# 270     12  2019  Monarch, Captive-Reared  30+_TO_35
# 271     12  2019  Monarch, Captive-Reared  35+_TO_40
# 272     12  2020  Monarch, Captive-Reared  25+_TO_30
# 273     12  2020  Monarch, Captive-Reared  30+_TO_35
# 274     12  2020  Monarch, Captive-Reared  35+_TO_40
#
#      captive_reared_distinct_dates
# 0                                4
# 1                                5
# 2                                3
# 3                                9
# 4                                2
# ..                             ...
# 270                             19
# 271                              1
# ...

# %%
JNorth1996_2020_CapRearsite_species =JNorth_CapRear_Site_df.groupby(['month','year','species', 'lat_range'])['number'].sum().reset_index()
JNorth1996_2020_CapRearsite_species
# Out:
#      month  year                  species  lat_range  number
# 0        1  2016  Monarch, Captive-Reared  25+_TO_30      17
# 1        1  2016  Monarch, Captive-Reared  30+_TO_35      19
# 2        1  2017  Monarch, Captive-Reared  25+_TO_30      27
# 3        1  2017  Monarch, Captive-Reared  30+_TO_35      24
# 4        1  2017  Monarch, Captive-Reared  35+_TO_40      47
# ..     ...   ...                      ...        ...     ...
# 270     12  2019  Monarch, Captive-Reared  30+_TO_35     406
# 271     12  2019  Monarch, Captive-Reared  35+_TO_40      23
# 272     12  2020  Monarch, Captive-Reared  25+_TO_30      49
# 273     12  2020  Monarch, Captive-Reared  30+_TO_35     624
# 274     12  2020  Monarch, Captive-Reared  35+_TO_40       7
#
# [275 rows x 5 columns]

# %%
JNorth_CapRear_Site_dt_df['captive_reared_number']= JNorth1996_2020_CapRearsite_species['number']
JNorth_CapRear_Site_dt_df['captive_reared_distinct_dates']= JNorth1996_2020_CapRearsite_d_dates['captive_reared_distinct_dates']
JNorth_CapRear_Site_dt_df
# Out:
#      month  year                  species  lat_range  captive_reared_dates  \
# 0        1  2016  Monarch, Captive-Reared  25+_TO_30                     5
# 1        1  2016  Monarch, Captive-Reared  30+_TO_35                     6
# 2        1  2017  Monarch, Captive-Reared  25+_TO_30                     4
# 3        1  2017  Monarch, Captive-Reared  30+_TO_35                    12
# 4        1  2017  Monarch, Captive-Reared  35+_TO_40                     2
# ..     ...   ...                      ...        ...                   ...
# 270     12  2019  Monarch, Captive-Reared  30+_TO_35                    25
# 271     12  2019  Monarch, Captive-Reared  35+_TO_40                     1
# 272     12  2020  Monarch, Captive-Reared  25+_TO_30                     6
# 273     12  2020  Monarch, Captive-Reared  30+_TO_35                    14
# 274     12  2020  Monarch, Captive-Reared  35+_TO_40                     3
#
#      captive_reared_number  captive_reared_distinct_dates
# ...

# %%
JNorth_CapRear_Site_dt_df.drop(['species'], axis=1, inplace=True)
JNorth_CapRear_Site_dt_df
# Out:
#      month  year  lat_range  captive_reared_dates  captive_reared_number  \
# 0        1  2016  25+_TO_30                     5                     17
# 1        1  2016  30+_TO_35                     6                     19
# 2        1  2017  25+_TO_30                     4                     27
# 3        1  2017  30+_TO_35                    12                     24
# 4        1  2017  35+_TO_40                     2                     47
# ..     ...   ...        ...                   ...                    ...
# 270     12  2019  30+_TO_35                    25                    406
# 271     12  2019  35+_TO_40                     1                     23
# 272     12  2020  25+_TO_30                     6                     49
# 273     12  2020  30+_TO_35                    14                    624
# 274     12  2020  35+_TO_40                     3                      7
#
#      captive_reared_distinct_dates
# 0                                4
# ...

# %%
JNorth_CapRear_Site_dt_df.shape
# Out:
# (275, 6)

# %%
JNorth_CapRear_Site_dt_df.to_csv('JNorth_Captive_Reared_Summary_Pivot.csv', header=True, mode='w', index=False)

# %% [markdown]
# # Milkweed Sighted Pivot

# %%
# filtering by type of observation (Milkweed Sighted)
JNorth_Milkweed_Site_df = JNorth1996_2020_df[JNorth1996_2020_df['species']=='Milkweed Sighted']
JNorth_Milkweed_Site_df.head()
# Out:
#        sighting_date           species  number   lat_range             site  \
# 93647     2016-05-01  Milkweed Sighted       1  20_OR_LESS   17.745--64.705
# 115957    2017-02-13  Milkweed Sighted       1   20+_TO_25  20.048--100.677
# 123052    2017-07-02  Milkweed Sighted       1   20+_TO_25    21.534--104.9
# 143330    2018-02-02  Milkweed Sighted       1   20+_TO_25  20.048--100.677
# 144736    2016-08-10  Milkweed Sighted       1   20+_TO_25    20.66--103.35
#
#         year  month
# 93647   2016      5
# 115957  2017      2
# 123052  2017      7
# 143330  2018      2
# 144736  2016      8

# %%
JNorth_Milkweed_Site_dt_df = JNorth_Milkweed_Site_df.groupby(['month','year','species', 'lat_range'])['sighting_date'].count().reset_index()
JNorth_Milkweed_Site_dt_df = pd.DataFrame(JNorth_Milkweed_Site_dt_df)

# %%
JNorth_Milkweed_Site_dt_df
# Out:
#      month  year           species  lat_range  sighting_date
# 0        1  2016  Milkweed Sighted  25+_TO_30              8
# 1        1  2016  Milkweed Sighted  30+_TO_35             10
# 2        1  2016  Milkweed Sighted  35+_TO_40              1
# 3        1  2017  Milkweed Sighted  30+_TO_35              2
# 4        1  2018  Milkweed Sighted  25+_TO_30              1
# ..     ...   ...               ...        ...            ...
# 123      7  2020  Milkweed Sighted  45+_TO_50              2
# 124      7  2020  Milkweed Sighted  4O+_TO_45             36
# 125      8  2016  Milkweed Sighted  20+_TO_25              1
# 126      9  2017  Milkweed Sighted  25+_TO_30              1
# 127     12  2016  Milkweed Sighted  30+_TO_35              1
#
# [128 rows x 5 columns]

# %%
JNorth_Milkweed_Site_dt_df.rename(columns={'sighting_date': 'milkweed_sight_dates'}, inplace=True)
JNorth_Milkweed_Site_dt_df
# Out:
#      month  year           species  lat_range  milkweed_sight_dates
# 0        1  2016  Milkweed Sighted  25+_TO_30                     8
# 1        1  2016  Milkweed Sighted  30+_TO_35                    10
# 2        1  2016  Milkweed Sighted  35+_TO_40                     1
# 3        1  2017  Milkweed Sighted  30+_TO_35                     2
# 4        1  2018  Milkweed Sighted  25+_TO_30                     1
# ..     ...   ...               ...        ...                   ...
# 123      7  2020  Milkweed Sighted  45+_TO_50                     2
# 124      7  2020  Milkweed Sighted  4O+_TO_45                    36
# 125      8  2016  Milkweed Sighted  20+_TO_25                     1
# 126      9  2017  Milkweed Sighted  25+_TO_30                     1
# 127     12  2016  Milkweed Sighted  30+_TO_35                     1
#
# [128 rows x 5 columns]

# %%
JNorth1996_2020_Milkweedsite_d_dates = JNorth_Milkweed_Site_df.groupby(['month','year','species', 'lat_range'])['sighting_date'].nunique().reset_index()
JNorth1996_2020_Milkweedsite_d_dates = pd.DataFrame(JNorth1996_2020_Milkweedsite_d_dates)
JNorth1996_2020_Milkweedsite_d_dates
# Out:
#      month  year           species  lat_range  sighting_date
# 0        1  2016  Milkweed Sighted  25+_TO_30              7
# 1        1  2016  Milkweed Sighted  30+_TO_35              7
# 2        1  2016  Milkweed Sighted  35+_TO_40              1
# 3        1  2017  Milkweed Sighted  30+_TO_35              2
# 4        1  2018  Milkweed Sighted  25+_TO_30              1
# ..     ...   ...               ...        ...            ...
# 123      7  2020  Milkweed Sighted  45+_TO_50              1
# 124      7  2020  Milkweed Sighted  4O+_TO_45             20
# 125      8  2016  Milkweed Sighted  20+_TO_25              1
# 126      9  2017  Milkweed Sighted  25+_TO_30              1
# 127     12  2016  Milkweed Sighted  30+_TO_35              1
#
# [128 rows x 5 columns]

# %%
JNorth1996_2020_Milkweedsite_d_dates.rename(columns={'sighting_date': 'milkweed_sight_distinct_dates'}, inplace=True)
JNorth1996_2020_Milkweedsite_d_dates
# Out:
#      month  year           species  lat_range  milkweed_sight_distinct_dates
# 0        1  2016  Milkweed Sighted  25+_TO_30                              7
# 1        1  2016  Milkweed Sighted  30+_TO_35                              7
# 2        1  2016  Milkweed Sighted  35+_TO_40                              1
# 3        1  2017  Milkweed Sighted  30+_TO_35                              2
# 4        1  2018  Milkweed Sighted  25+_TO_30                              1
# ..     ...   ...               ...        ...                            ...
# 123      7  2020  Milkweed Sighted  45+_TO_50                              1
# 124      7  2020  Milkweed Sighted  4O+_TO_45                             20
# 125      8  2016  Milkweed Sighted  20+_TO_25                              1
# 126      9  2017  Milkweed Sighted  25+_TO_30                              1
# 127     12  2016  Milkweed Sighted  30+_TO_35                              1
#
# [128 rows x 5 columns]

# %%
JNorth1996_2020_Milkweedsite_species =JNorth_Milkweed_Site_df.groupby(['month','year','species', 'lat_range'])['number'].sum().reset_index()
JNorth1996_2020_Milkweedsite_species
# Out:
#      month  year           species  lat_range  number
# 0        1  2016  Milkweed Sighted  25+_TO_30       8
# 1        1  2016  Milkweed Sighted  30+_TO_35      10
# 2        1  2016  Milkweed Sighted  35+_TO_40       1
# 3        1  2017  Milkweed Sighted  30+_TO_35       2
# 4        1  2018  Milkweed Sighted  25+_TO_30       1
# ..     ...   ...               ...        ...     ...
# 123      7  2020  Milkweed Sighted  45+_TO_50       2
# 124      7  2020  Milkweed Sighted  4O+_TO_45      36
# 125      8  2016  Milkweed Sighted  20+_TO_25       1
# 126      9  2017  Milkweed Sighted  25+_TO_30       1
# 127     12  2016  Milkweed Sighted  30+_TO_35       1
#
# [128 rows x 5 columns]

# %%
JNorth_Milkweed_Site_dt_df['milkweed_sight_number']= JNorth1996_2020_Milkweedsite_species['number']
JNorth_Milkweed_Site_dt_df['milkweed_sight_distinct_dates']= JNorth1996_2020_Milkweedsite_d_dates['milkweed_sight_distinct_dates']
JNorth_Milkweed_Site_dt_df
# Out:
#      month  year           species  lat_range  milkweed_sight_dates  \
# 0        1  2016  Milkweed Sighted  25+_TO_30                     8
# 1        1  2016  Milkweed Sighted  30+_TO_35                    10
# 2        1  2016  Milkweed Sighted  35+_TO_40                     1
# 3        1  2017  Milkweed Sighted  30+_TO_35                     2
# 4        1  2018  Milkweed Sighted  25+_TO_30                     1
# ..     ...   ...               ...        ...                   ...
# 123      7  2020  Milkweed Sighted  45+_TO_50                     2
# 124      7  2020  Milkweed Sighted  4O+_TO_45                    36
# 125      8  2016  Milkweed Sighted  20+_TO_25                     1
# 126      9  2017  Milkweed Sighted  25+_TO_30                     1
# 127     12  2016  Milkweed Sighted  30+_TO_35                     1
#
#      milkweed_sight_number  milkweed_sight_distinct_dates
# 0                        8                              7
# ...

# %%
JNorth_Milkweed_Site_dt_df.drop(['species'], axis=1, inplace=True)
JNorth_Milkweed_Site_dt_df
# Out:
#      month  year  lat_range  milkweed_sight_dates  milkweed_sight_number  \
# 0        1  2016  25+_TO_30                     8                      8
# 1        1  2016  30+_TO_35                    10                     10
# 2        1  2016  35+_TO_40                     1                      1
# 3        1  2017  30+_TO_35                     2                      2
# 4        1  2018  25+_TO_30                     1                      1
# ..     ...   ...        ...                   ...                    ...
# 123      7  2020  45+_TO_50                     2                      2
# 124      7  2020  4O+_TO_45                    36                     36
# 125      8  2016  20+_TO_25                     1                      1
# 126      9  2017  25+_TO_30                     1                      1
# 127     12  2016  30+_TO_35                     1                      1
#
#      milkweed_sight_distinct_dates
# 0                                7
# ...

# %%
JNorth_Milkweed_Site_dt_df.shape
# Out:
# (128, 6)

# %%
JNorth_Milkweed_Site_dt_df.to_csv('JNorth_Milkweed_Sighting_Summary_Pivot.csv', header=True, mode='w', index=False)

# %% [markdown]
# # BASE

# %%
JNorth1996_2020_df_sites =JNorth1996_2020_df.groupby(['month','year','species', 'lat_range'])['site'].nunique().reset_index()
JNorth1996_2020_df_sites
# Out:
#       month  year                        species  lat_range  site
# 0         1  1997          Monarch Adult Sighted  30+_TO_35     1
# 1         1  1998  Monarch Adult (FIRST sighted)  25+_TO_30     3
# 2         1  1998    Monarch Egg (FIRST sighted)  25+_TO_30     1
# 3         1  1999   Monarch (OTHER Observations)  25+_TO_30     1
# 4         1  1999  Monarch Adult (FIRST sighted)  25+_TO_30     2
# ...     ...   ...                            ...        ...   ...
# 5810     12  2020          Monarch Larva Sighted  30+_TO_35    31
# 5811     12  2020          Monarch Larva Sighted  35+_TO_40     1
# 5812     12  2020        Monarch, Captive-Reared  25+_TO_30     6
# 5813     12  2020        Monarch, Captive-Reared  30+_TO_35    11
# 5814     12  2020        Monarch, Captive-Reared  35+_TO_40     1
#
# [5815 rows x 5 columns]

# %%
JNorth1996_2020_site_dates = JNorth1996_2020_df.groupby(['month','year','species', 'lat_range'])['sighting_date'].count().reset_index()
JNorth1996_2020_site_dates = pd.DataFrame(JNorth1996_2020_site_dates)

# %%
JNorth1996_2020_site_dates.rename(columns={'sighting_date': 'sighting_dates'}, inplace=True)
JNorth1996_2020_site_dates
# Out:
#       month  year                        species  lat_range  sighting_dates
# 0         1  1997          Monarch Adult Sighted  30+_TO_35               1
# 1         1  1998  Monarch Adult (FIRST sighted)  25+_TO_30               3
# 2         1  1998    Monarch Egg (FIRST sighted)  25+_TO_30               1
# 3         1  1999   Monarch (OTHER Observations)  25+_TO_30               3
# 4         1  1999  Monarch Adult (FIRST sighted)  25+_TO_30               2
# ...     ...   ...                            ...        ...             ...
# 5810     12  2020          Monarch Larva Sighted  30+_TO_35              40
# 5811     12  2020          Monarch Larva Sighted  35+_TO_40               1
# 5812     12  2020        Monarch, Captive-Reared  25+_TO_30               6
# 5813     12  2020        Monarch, Captive-Reared  30+_TO_35              14
# 5814     12  2020        Monarch, Captive-Reared  35+_TO_40               3
#
# [5815 rows x 5 columns]

# %%
JNorth1996_2020_site_dates
# Out:
#       month  year                        species  lat_range  sighting_dates
# 0         1  1997          Monarch Adult Sighted  30+_TO_35               1
# 1         1  1998  Monarch Adult (FIRST sighted)  25+_TO_30               3
# 2         1  1998    Monarch Egg (FIRST sighted)  25+_TO_30               1
# 3         1  1999   Monarch (OTHER Observations)  25+_TO_30               3
# 4         1  1999  Monarch Adult (FIRST sighted)  25+_TO_30               2
# ...     ...   ...                            ...        ...             ...
# 5810     12  2020          Monarch Larva Sighted  30+_TO_35              40
# 5811     12  2020          Monarch Larva Sighted  35+_TO_40               1
# 5812     12  2020        Monarch, Captive-Reared  25+_TO_30               6
# 5813     12  2020        Monarch, Captive-Reared  30+_TO_35              14
# 5814     12  2020        Monarch, Captive-Reared  35+_TO_40               3
#
# [5815 rows x 5 columns]

# %%
JNorth1996_2020_site_d_dates = JNorth1996_2020_df.groupby(['month','year','species', 'lat_range'])['sighting_date'].nunique().reset_index()
JNorth1996_2020_site_d_dates = pd.DataFrame(JNorth1996_2020_site_d_dates)
JNorth1996_2020_site_d_dates
# Out:
#       month  year                        species  lat_range  sighting_date
# 0         1  1997          Monarch Adult Sighted  30+_TO_35              1
# 1         1  1998  Monarch Adult (FIRST sighted)  25+_TO_30              3
# 2         1  1998    Monarch Egg (FIRST sighted)  25+_TO_30              1
# 3         1  1999   Monarch (OTHER Observations)  25+_TO_30              3
# 4         1  1999  Monarch Adult (FIRST sighted)  25+_TO_30              2
# ...     ...   ...                            ...        ...            ...
# 5810     12  2020          Monarch Larva Sighted  30+_TO_35             22
# 5811     12  2020          Monarch Larva Sighted  35+_TO_40              1
# 5812     12  2020        Monarch, Captive-Reared  25+_TO_30              4
# 5813     12  2020        Monarch, Captive-Reared  30+_TO_35             10
# 5814     12  2020        Monarch, Captive-Reared  35+_TO_40              3
#
# [5815 rows x 5 columns]

# %%
JNorth1996_2020_site_d_dates.rename(columns={'sighting_date': 'sighting_distinct_dates'}, inplace=True)
JNorth1996_2020_site_d_dates
# Out:
#       month  year                        species  lat_range  \
# 0         1  1997          Monarch Adult Sighted  30+_TO_35
# 1         1  1998  Monarch Adult (FIRST sighted)  25+_TO_30
# 2         1  1998    Monarch Egg (FIRST sighted)  25+_TO_30
# 3         1  1999   Monarch (OTHER Observations)  25+_TO_30
# 4         1  1999  Monarch Adult (FIRST sighted)  25+_TO_30
# ...     ...   ...                            ...        ...
# 5810     12  2020          Monarch Larva Sighted  30+_TO_35
# 5811     12  2020          Monarch Larva Sighted  35+_TO_40
# 5812     12  2020        Monarch, Captive-Reared  25+_TO_30
# 5813     12  2020        Monarch, Captive-Reared  30+_TO_35
# 5814     12  2020        Monarch, Captive-Reared  35+_TO_40
#
#       sighting_distinct_dates
# 0                           1
# 1                           3
# 2                           1
# 3                           3
# 4                           2
# ...                       ...
# ...

# %%
JNorth1996_2020_df_species =JNorth1996_2020_df.groupby(['month','year','species', 'lat_range'])['number'].sum().reset_index()
JNorth1996_2020_df_species
# Out:
#       month  year                        species  lat_range  number
# 0         1  1997          Monarch Adult Sighted  30+_TO_35       1
# 1         1  1998  Monarch Adult (FIRST sighted)  25+_TO_30       3
# 2         1  1998    Monarch Egg (FIRST sighted)  25+_TO_30       1
# 3         1  1999   Monarch (OTHER Observations)  25+_TO_30       3
# 4         1  1999  Monarch Adult (FIRST sighted)  25+_TO_30       2
# ...     ...   ...                            ...        ...     ...
# 5810     12  2020          Monarch Larva Sighted  30+_TO_35     250
# 5811     12  2020          Monarch Larva Sighted  35+_TO_40      21
# 5812     12  2020        Monarch, Captive-Reared  25+_TO_30      49
# 5813     12  2020        Monarch, Captive-Reared  30+_TO_35     624
# 5814     12  2020        Monarch, Captive-Reared  35+_TO_40       7
#
# [5815 rows x 5 columns]

# %%
JNorth1996_2020_site_dates['number']= JNorth1996_2020_df_species['number']
JNorth1996_2020_site_dates['sighting_distinct_dates']= JNorth1996_2020_site_d_dates['sighting_distinct_dates']
JNorth1996_2020_site_dates
# Out:
#       month  year                        species  lat_range  sighting_dates  \
# 0         1  1997          Monarch Adult Sighted  30+_TO_35               1
# 1         1  1998  Monarch Adult (FIRST sighted)  25+_TO_30               3
# 2         1  1998    Monarch Egg (FIRST sighted)  25+_TO_30               1
# 3         1  1999   Monarch (OTHER Observations)  25+_TO_30               3
# 4         1  1999  Monarch Adult (FIRST sighted)  25+_TO_30               2
# ...     ...   ...                            ...        ...             ...
# 5810     12  2020          Monarch Larva Sighted  30+_TO_35              40
# 5811     12  2020          Monarch Larva Sighted  35+_TO_40               1
# 5812     12  2020        Monarch, Captive-Reared  25+_TO_30               6
# 5813     12  2020        Monarch, Captive-Reared  30+_TO_35              14
# 5814     12  2020        Monarch, Captive-Reared  35+_TO_40               3
#
#       number  sighting_distinct_dates
# ...

# %%
JNorth1996_2020_site_dates
# Out:
#       month  year                        species  lat_range  sighting_dates  \
# 0         1  1997          Monarch Adult Sighted  30+_TO_35               1
# 1         1  1998  Monarch Adult (FIRST sighted)  25+_TO_30               3
# 2         1  1998    Monarch Egg (FIRST sighted)  25+_TO_30               1
# 3         1  1999   Monarch (OTHER Observations)  25+_TO_30               3
# 4         1  1999  Monarch Adult (FIRST sighted)  25+_TO_30               2
# ...     ...   ...                            ...        ...             ...
# 5810     12  2020          Monarch Larva Sighted  30+_TO_35              40
# 5811     12  2020          Monarch Larva Sighted  35+_TO_40               1
# 5812     12  2020        Monarch, Captive-Reared  25+_TO_30               6
# 5813     12  2020        Monarch, Captive-Reared  30+_TO_35              14
# 5814     12  2020        Monarch, Captive-Reared  35+_TO_40               3
#
#       number  sighting_distinct_dates
# ...

# %%
JNorth1996_2020_df_sites =JNorth1996_2020_df.groupby(['month','year','species', 'lat_range'])['site'].nunique().reset_index()
JNorth1996_2020_df_sites
# Out:
#       month  year                        species  lat_range  site
# 0         1  1997          Monarch Adult Sighted  30+_TO_35     1
# 1         1  1998  Monarch Adult (FIRST sighted)  25+_TO_30     3
# 2         1  1998    Monarch Egg (FIRST sighted)  25+_TO_30     1
# 3         1  1999   Monarch (OTHER Observations)  25+_TO_30     1
# 4         1  1999  Monarch Adult (FIRST sighted)  25+_TO_30     2
# ...     ...   ...                            ...        ...   ...
# 5810     12  2020          Monarch Larva Sighted  30+_TO_35    31
# 5811     12  2020          Monarch Larva Sighted  35+_TO_40     1
# 5812     12  2020        Monarch, Captive-Reared  25+_TO_30     6
# 5813     12  2020        Monarch, Captive-Reared  30+_TO_35    11
# 5814     12  2020        Monarch, Captive-Reared  35+_TO_40     1
#
# [5815 rows x 5 columns]

# %%
JNorth1996_2020_site_dates['sites']= JNorth1996_2020_df_sites['site']
JNorth1996_2020_site_dates.tail(10)
# Out:
#       month  year                        species  lat_range  sighting_dates  \
# 5805     12  2020            Monarch Egg Sighted  25+_TO_30              34
# 5806     12  2020            Monarch Egg Sighted  30+_TO_35               5
# 5807     12  2020  Monarch Larva (FIRST sighted)  30+_TO_35               1
# 5808     12  2020          Monarch Larva Sighted  20+_TO_25               1
# 5809     12  2020          Monarch Larva Sighted  25+_TO_30              62
# 5810     12  2020          Monarch Larva Sighted  30+_TO_35              40
# 5811     12  2020          Monarch Larva Sighted  35+_TO_40               1
# 5812     12  2020        Monarch, Captive-Reared  25+_TO_30               6
# 5813     12  2020        Monarch, Captive-Reared  30+_TO_35              14
# 5814     12  2020        Monarch, Captive-Reared  35+_TO_40               3
#
#       number  sighting_distinct_dates  sites
# 5805     183                       13     21
# ...

# %%
JNorth1996_2020_site_dates.dtypes
# Out:
# month                       int64
# year                        int64
# species                    object
# lat_range                  object
# sighting_dates              int64
# number                      int64
# sighting_distinct_dates     int64
# sites                       int64
# dtype: object

# %% [markdown]
# # Monarch Watch Overwintering Population estimates

# %%
MWatchOW_df = pd.read_csv("../../resources/MWatch_overwintering/Monarch_Overwintering_Occupied_Area_Est_Population.csv")
MWatchOW_df.head(15)
# Out:
#     Season_Start  Season_End  Hectares_Occupied_Start  Hectares_Occupied_End
# 0           1994        1995                     6.23                   7.81
# 1           1995        1996                     7.81                  12.61
# 2           1996        1997                    12.61                  18.19
# 3           1997        1998                    18.19                   5.77
# 4           1998        1999                     5.77                   5.56
# 5           1999        2000                     5.56                   9.05
# 6           2000        2001                     9.05                   2.83
# 7           2001        2002                     2.83                   9.36
# 8           2002        2003                     9.36                   7.54
# 9           2003        2004                     7.54                  11.12
# 10          2004        2005                    11.12                   2.19
# ...

# %%
MWatchG = MWatchOW_df
MWatchG.drop(['Season_Start'], axis=1, inplace=True)

# %%
df = MWatchG 
# df = pd.DataFrame({"year": [1914,1915,1916,1919,1920],
#                    "action" : [2.6,3.4,3.25,2.8,1.75],
#                    "comedy" : [2.5,2.9,3.0,3.3,3.4] })
# df.plot(x="year", y=["action", "comedy"])
df.plot(figsize = (20,5), x ='Season_End', y = ['Hectares_Occupied_End'])
# plt.show()

# df.plot(figsize = (20,5)) #, ylabel ='Fare ($USD))', xlabel ="")

# Import the style from Matplotlib.
from matplotlib import style
# Use the graph style fivethirtyeight.
style.use('fivethirtyeight')

# %%
MWatchOW_df.rename(columns={'Season_Start': 'year'}, inplace=True)

# %%
MWatchOW_df.dtypes
# Out:
# year                         int64
# Season_End                   int64
# Hectares_Occupied_Start    float64
# Hectares_Occupied_End      float64
# dtype: object

# %%
JNorth1996_2020_site_summary= pd.merge(JNorth1996_2020_site_dates, MWatchOW_df, how="left", on=["year", "year"])
JNorth1996_2020_site_summary.tail(30)
# Out:
#       month  year                        species   lat_range  sighting_dates  \
# 5785     12  2019            Monarch Egg Sighted   25+_TO_30               4
# 5786     12  2019            Monarch Egg Sighted   30+_TO_35               1
# 5787     12  2019  Monarch Larva (FIRST sighted)   30+_TO_35               1
# 5788     12  2019          Monarch Larva Sighted   25+_TO_30              20
# 5789     12  2019          Monarch Larva Sighted   30+_TO_35              13
# 5790     12  2019          Monarch Larva Sighted   35+_TO_40               1
# 5791     12  2019        Monarch, Captive-Reared   25+_TO_30               2
# 5792     12  2019        Monarch, Captive-Reared   30+_TO_35              25
# 5793     12  2019        Monarch, Captive-Reared   35+_TO_40               1
# 5794     12  2020   Monarch (OTHER Observations)   20+_TO_25               1
# 5795     12  2020   Monarch (OTHER Observations)   25+_TO_30               6
# ...

# %% [markdown]
# # Monarch Tag Recovery Mexico

# %%
MWatch_TR_Mex_df = pd.read_csv("../../resources/MWatch_recoveries/MWatch_Tag Recoveries_Mexico_2020.csv")
MWatch_TR_Mex_df.head(15)
# Out:
#    Tag Code  Report Season    Location  latitude  longitude
# 0     775IZ           2020  El Rosario   30.0595  -115.7257
# 1   AAAB310           2020  El Rosario   30.0595  -115.7257
# 2   AAAE401           2020  El Rosario   30.0595  -115.7257
# 3   AAAE620           2020  El Rosario   30.0595  -115.7257
# 4   AAAM653           2020  El Rosario   30.0595  -115.7257
# 5   AAAN163           2020  El Rosario   30.0595  -115.7257
# 6   AAAR048           2020  El Rosario   30.0595  -115.7257
# 7   AAAW641           2020  El Rosario   30.0595  -115.7257
# 8   AABA649           2020  El Rosario   30.0595  -115.7257
# 9   AABB388           2020  El Rosario   30.0595  -115.7257
# 10  AABB895           2020  El Rosario   30.0595  -115.7257
# 11  AABC305           2020  El Rosario   30.0595  -115.7257
# 12  AACM749           2020  El Rosario   30.0595  -115.7257
# 13  AACM779           2020  El Rosario   30.0595  -115.7257
# 14  AACS031           2020  El Rosario   30.0595  -115.7257

# %%
MWatch_TR_Mex_df['species'] = 'Monarch Tag Recovery'
MWatch_TR_Mex_df
# Out:
#       Tag Code  Report Season          Location   latitude   longitude  \
# 0        775IZ           2020        El Rosario  30.059500 -115.725700
# 1      AAAB310           2020        El Rosario  30.059500 -115.725700
# 2      AAAE401           2020        El Rosario  30.059500 -115.725700
# 3      AAAE620           2020        El Rosario  30.059500 -115.725700
# 4      AAAM653           2020        El Rosario  30.059500 -115.725700
# ...        ...            ...               ...        ...         ...
# 20078   HEX743           2006       Mil Cumbres  19.696600 -101.144600
# 20079   AIU819           2004       Mil Cumbres  19.696600 -101.144600
# 20080   HBR238           2006  Cerro Altamirano  18.357816 -100.668626
# 20081   HEN350           2006  Cerro Altamirano  18.357816 -100.668626
# 20082   HGR697           2006  Cerro Altamirano  18.357816 -100.668626
#
#                     species
# 0      Monarch Tag Recovery
# 1      Monarch Tag Recovery
# ...

# %%
MWatchTwentyOrLess = MWatch_TR_Mex_df.loc[(MWatch_TR_Mex_df['latitude']<=20)]
MWatchTwentyOrLess = pd.DataFrame(MWatchTwentyOrLess)
MWatchTwentyOrLess['lat_range'] = '20_OR_LESS'
MWatchTwentyOrLess
# Out:
#       Tag Code  Report Season          Location   latitude   longitude  \
# 15876  AAAE280           2020       Cerro Pelon  19.025000 -100.142000
# 15877  AAAY017           2020       Cerro Pelon  19.025000 -100.142000
# 15878  AACH693           2020       Cerro Pelon  19.025000 -100.142000
# 15879  AAER417           2020       Cerro Pelon  19.025000 -100.142000
# 15880  AAEY458           2020       Cerro Pelon  19.025000 -100.142000
# ...        ...            ...               ...        ...         ...
# 20078   HEX743           2006       Mil Cumbres  19.696600 -101.144600
# 20079   AIU819           2004       Mil Cumbres  19.696600 -101.144600
# 20080   HBR238           2006  Cerro Altamirano  18.357816 -100.668626
# 20081   HEN350           2006  Cerro Altamirano  18.357816 -100.668626
# 20082   HGR697           2006  Cerro Altamirano  18.357816 -100.668626
#
#                     species   lat_range
# 15876  Monarch Tag Recovery  20_OR_LESS
# ...

# %%
MWatchTwentyPlusToTwentyFive = MWatch_TR_Mex_df.loc[(MWatch_TR_Mex_df['latitude']>20) & (MWatch_TR_Mex_df['latitude']<=25)]
MWatchTwentyPlusToTwentyFive = pd.DataFrame(MWatchTwentyPlusToTwentyFive)
MWatchTwentyPlusToTwentyFive['lat_range'] = '20+_TO_25'
MWatchTwentyPlusToTwentyFive
# Out:
#       Tag Code  Report Season          Location   latitude   longitude  \
# 18259  AAEC839           2020    Sierra Chincua  20.117667 -100.463667
# 18260  AANS493           2020    Sierra Chincua  20.117667 -100.463667
# 18261  AAUB464           2020    Sierra Chincua  20.117667 -100.463667
# 18262  AAUL558           2020    Sierra Chincua  20.117667 -100.463667
# 18263  AAYR063           2020    Sierra Chincua  20.117667 -100.463667
# ...        ...            ...               ...        ...         ...
# 20071    835HQ           1999       Las Palomas  20.921944 -100.740278
# 20072   EEG797           2007  Canada Del Salto  21.398000 -101.455000
# 20073   GRB554           2007  Canada Del Salto  21.398000 -101.455000
# 20074   JCB874           2007  Canada Del Salto  21.398000 -101.455000
# 20075   JCW778           2007  Canada Del Salto  21.398000 -101.455000
#
#                     species  lat_range
# 18259  Monarch Tag Recovery  20+_TO_25
# ...

# %%
MWatchTwentyFivePlusToThirty = MWatch_TR_Mex_df.loc[(MWatch_TR_Mex_df['latitude']>25) & (MWatch_TR_Mex_df['latitude']<=30)]
MWatchTwentyFivePlusToThirty = pd.DataFrame(MWatchTwentyFivePlusToThirty)
MWatchTwentyFivePlusToThirty['lat_range'] = '25+_TO_30'
MWatchTwentyFivePlusToThirty
# Out:
#       Tag Code  Report Season Location  latitude   longitude  \
# 20027   PHB928           2011   Ocampo    27.526 -102.660833
#
#                     species  lat_range
# 20027  Monarch Tag Recovery  25+_TO_30

# %%
MWatchThirtyPlusToThirtyFive = MWatch_TR_Mex_df.loc[(MWatch_TR_Mex_df['latitude']>30) & (MWatch_TR_Mex_df['latitude']<=35)]
MWatchThirtyPlusToThirtyFive = pd.DataFrame(MWatchThirtyPlusToThirtyFive)
MWatchThirtyPlusToThirtyFive['lat_range'] = '30+_TO_35'
MWatchThirtyPlusToThirtyFive
# Out:
#       Tag Code  Report Season    Location  latitude  longitude  \
# 0        775IZ           2020  El Rosario   30.0595  -115.7257
# 1      AAAB310           2020  El Rosario   30.0595  -115.7257
# 2      AAAE401           2020  El Rosario   30.0595  -115.7257
# 3      AAAE620           2020  El Rosario   30.0595  -115.7257
# 4      AAAM653           2020  El Rosario   30.0595  -115.7257
# ...        ...            ...         ...       ...        ...
# 15871    AU646           1995  El Rosario   30.0595  -115.7257
# 15872    BP144           1995  El Rosario   30.0595  -115.7257
# 15873    BW003           1995  El Rosario   30.0595  -115.7257
# 15874    CM355           1995  El Rosario   30.0595  -115.7257
# 15875    160AF           1993  El Rosario   30.0595  -115.7257
#
#                     species  lat_range
# 0      Monarch Tag Recovery  30+_TO_35
# 1      Monarch Tag Recovery  30+_TO_35
# 2      Monarch Tag Recovery  30+_TO_35
# 3      Monarch Tag Recovery  30+_TO_35
# ...

# %%
frames = [MWatchTwentyOrLess, MWatchTwentyPlusToTwentyFive, MWatchTwentyFivePlusToThirty,MWatchThirtyPlusToThirtyFive]
MWatch_TR_Mex_df = pd.concat(frames)
MWatch_TR_Mex_df.head(10)
# Out:
#       Tag Code  Report Season     Location  latitude  longitude  \
# 15876  AAAE280           2020  Cerro Pelon    19.025   -100.142
# 15877  AAAY017           2020  Cerro Pelon    19.025   -100.142
# 15878  AACH693           2020  Cerro Pelon    19.025   -100.142
# 15879  AAER417           2020  Cerro Pelon    19.025   -100.142
# 15880  AAEY458           2020  Cerro Pelon    19.025   -100.142
# 15881  AALS247           2020  Cerro Pelon    19.025   -100.142
# 15882  AAMH018           2020  Cerro Pelon    19.025   -100.142
# 15883  AAML280           2020  Cerro Pelon    19.025   -100.142
# 15884  AAMN253           2020  Cerro Pelon    19.025   -100.142
# 15885  AAMZ536           2020  Cerro Pelon    19.025   -100.142
#
#                     species   lat_range
# 15876  Monarch Tag Recovery  20_OR_LESS
# 15877  Monarch Tag Recovery  20_OR_LESS
# 15878  Monarch Tag Recovery  20_OR_LESS
# 15879  Monarch Tag Recovery  20_OR_LESS
# 15880  Monarch Tag Recovery  20_OR_LESS
# ...

# %%
MWatch_TR_Mex_df = MWatch_TR_Mex_df
MWatch_TR_Mex_df['site'] = MWatch_TR_Mex_df[['latitude', 'longitude']].astype(str).agg('-'.join, axis=1)
MWatch_TR_Mex_df
# Out:
#       Tag Code  Report Season     Location  latitude  longitude  \
# 15876  AAAE280           2020  Cerro Pelon   19.0250  -100.1420
# 15877  AAAY017           2020  Cerro Pelon   19.0250  -100.1420
# 15878  AACH693           2020  Cerro Pelon   19.0250  -100.1420
# 15879  AAER417           2020  Cerro Pelon   19.0250  -100.1420
# 15880  AAEY458           2020  Cerro Pelon   19.0250  -100.1420
# ...        ...            ...          ...       ...        ...
# 15871    AU646           1995   El Rosario   30.0595  -115.7257
# 15872    BP144           1995   El Rosario   30.0595  -115.7257
# 15873    BW003           1995   El Rosario   30.0595  -115.7257
# 15874    CM355           1995   El Rosario   30.0595  -115.7257
# 15875    160AF           1993   El Rosario   30.0595  -115.7257
#
#                     species   lat_range               site
# 15876  Monarch Tag Recovery  20_OR_LESS    19.025--100.142
# 15877  Monarch Tag Recovery  20_OR_LESS    19.025--100.142
# ...

# %%
MWatch_TR_Mex_df.drop(['latitude','longitude','Location'], axis=1, inplace=True)
MWatch_TR_Mex_df.head()
# Out:
#       Tag Code  Report Season               species   lat_range  \
# 15876  AAAE280           2020  Monarch Tag Recovery  20_OR_LESS
# 15877  AAAY017           2020  Monarch Tag Recovery  20_OR_LESS
# 15878  AACH693           2020  Monarch Tag Recovery  20_OR_LESS
# 15879  AAER417           2020  Monarch Tag Recovery  20_OR_LESS
# 15880  AAEY458           2020  Monarch Tag Recovery  20_OR_LESS
#
#                   site
# 15876  19.025--100.142
# 15877  19.025--100.142
# 15878  19.025--100.142
# 15879  19.025--100.142
# 15880  19.025--100.142

# %%
MWatch_TR_Mex_number_df =MWatch_TR_Mex_df.groupby(['Report Season','species', 'lat_range', 'site'])['Tag Code'].count().reset_index()
MWatch_TR_Mex_number_df
# Out:
#      Report Season               species   lat_range  \
# 0             1993  Monarch Tag Recovery   20+_TO_25
# 1             1993  Monarch Tag Recovery   30+_TO_35
# 2             1994  Monarch Tag Recovery  20_OR_LESS
# 3             1995  Monarch Tag Recovery   20+_TO_25
# 4             1995  Monarch Tag Recovery   20+_TO_25
# ..             ...                   ...         ...
# 128           2020  Monarch Tag Recovery   20+_TO_25
# 129           2020  Monarch Tag Recovery   20+_TO_25
# 130           2020  Monarch Tag Recovery  20_OR_LESS
# 131           2020  Monarch Tag Recovery  20_OR_LESS
# 132           2020  Monarch Tag Recovery   30+_TO_35
#
#                                        site  Tag Code
# 0     20.11766666666667--100.46366666666668         1
# 1                         30.0595--115.7257         1
# 2                            19.6167--100.3         8
# 3     20.11766666666667--100.46366666666668         7
# ...

# %%
MWatch_TR_Mex_number_df.rename(columns={'Tag Code': 'number'}, inplace=True)
MWatch_TR_Mex_number_df
# Out:
#      Report Season               species   lat_range  \
# 0             1993  Monarch Tag Recovery   20+_TO_25
# 1             1993  Monarch Tag Recovery   30+_TO_35
# 2             1994  Monarch Tag Recovery  20_OR_LESS
# 3             1995  Monarch Tag Recovery   20+_TO_25
# 4             1995  Monarch Tag Recovery   20+_TO_25
# ..             ...                   ...         ...
# 128           2020  Monarch Tag Recovery   20+_TO_25
# 129           2020  Monarch Tag Recovery   20+_TO_25
# 130           2020  Monarch Tag Recovery  20_OR_LESS
# 131           2020  Monarch Tag Recovery  20_OR_LESS
# 132           2020  Monarch Tag Recovery   30+_TO_35
#
#                                        site  number
# 0     20.11766666666667--100.46366666666668       1
# 1                         30.0595--115.7257       1
# 2                            19.6167--100.3       8
# 3     20.11766666666667--100.46366666666668       7
# 4    21.216666666666665--103.03133333333334       1
# ...

# %%
MWatch_TR_Mex_site_df =MWatch_TR_Mex_df.groupby(['Report Season','species', 'lat_range'])['site'].nunique().reset_index()
MWatch_TR_Mex_site_df
# Out:
#     Report Season               species   lat_range  site
# 0            1993  Monarch Tag Recovery   20+_TO_25     1
# 1            1993  Monarch Tag Recovery   30+_TO_35     1
# 2            1994  Monarch Tag Recovery  20_OR_LESS     1
# 3            1995  Monarch Tag Recovery   20+_TO_25     2
# 4            1995  Monarch Tag Recovery   30+_TO_35     1
# ..            ...                   ...         ...   ...
# 76           2019  Monarch Tag Recovery  20_OR_LESS     2
# 77           2019  Monarch Tag Recovery   30+_TO_35     1
# 78           2020  Monarch Tag Recovery   20+_TO_25     2
# 79           2020  Monarch Tag Recovery  20_OR_LESS     2
# 80           2020  Monarch Tag Recovery   30+_TO_35     1
#
# [81 rows x 4 columns]

# %%
MWatch_TR_Mex_site_df['number']= MWatch_TR_Mex_number_df['number']
MWatch_TR_Mex_site_df.tail()
# Out:
#     Report Season               species   lat_range  site  number
# 76           2019  Monarch Tag Recovery  20_OR_LESS     2       4
# 77           2019  Monarch Tag Recovery   30+_TO_35     1       5
# 78           2020  Monarch Tag Recovery   20+_TO_25     2       3
# 79           2020  Monarch Tag Recovery  20_OR_LESS     2      13
# 80           2020  Monarch Tag Recovery   30+_TO_35     1      43

# %%
MWatch_TR_Mex_df= pd.DataFrame(MWatch_TR_Mex_site_df)
MWatch_TR_Mex_df['month'] = 3
MWatch_TR_Mex_df['year'] = MWatch_TR_Mex_site_df['Report Season'] + 1
MWatch_TR_Mex_df
# Out:
#     Report Season               species   lat_range  site  number  month  year
# 0            1993  Monarch Tag Recovery   20+_TO_25     1       1      3  1994
# 1            1993  Monarch Tag Recovery   30+_TO_35     1       1      3  1994
# 2            1994  Monarch Tag Recovery  20_OR_LESS     1       8      3  1995
# 3            1995  Monarch Tag Recovery   20+_TO_25     2       7      3  1996
# 4            1995  Monarch Tag Recovery   30+_TO_35     1       1      3  1996
# ..            ...                   ...         ...   ...     ...    ...   ...
# 76           2019  Monarch Tag Recovery  20_OR_LESS     2       4      3  2020
# 77           2019  Monarch Tag Recovery   30+_TO_35     1       5      3  2020
# 78           2020  Monarch Tag Recovery   20+_TO_25     2       3      3  2021
# 79           2020  Monarch Tag Recovery  20_OR_LESS     2      13      3  2021
# 80           2020  Monarch Tag Recovery   30+_TO_35     1      43      3  2021
#
# [81 rows x 7 columns]

# %%
MWatch_TR_Mex_df.rename(columns={'Report Season': 'Season_Start'}, inplace=True)
cols = ['month','year', 'species', 'lat_range' ,'site', 'number', 'Season_Start']
MWatch_TR_Mex_df = pd.DataFrame(MWatch_TR_Mex_df[cols])
MWatch_TR_Mex_df
# Out:
#     month  year               species   lat_range  site  number  Season_Start
# 0       3  1994  Monarch Tag Recovery   20+_TO_25     1       1          1993
# 1       3  1994  Monarch Tag Recovery   30+_TO_35     1       1          1993
# 2       3  1995  Monarch Tag Recovery  20_OR_LESS     1       8          1994
# 3       3  1996  Monarch Tag Recovery   20+_TO_25     2       7          1995
# 4       3  1996  Monarch Tag Recovery   30+_TO_35     1       1          1995
# ..    ...   ...                   ...         ...   ...     ...           ...
# 76      3  2020  Monarch Tag Recovery  20_OR_LESS     2       4          2019
# 77      3  2020  Monarch Tag Recovery   30+_TO_35     1       5          2019
# 78      3  2021  Monarch Tag Recovery   20+_TO_25     2       3          2020
# 79      3  2021  Monarch Tag Recovery  20_OR_LESS     2      13          2020
# 80      3  2021  Monarch Tag Recovery   30+_TO_35     1      43          2020
#
# [81 rows x 7 columns]

# %% [markdown]
# # Billion Dollar Weather Events

# %%
bd_weather_df = pd.read_csv("../../resources/ncdc_noaa_gov_bd_weather_events/bd_weather_events.csv")
bd_weather_df.head(15)
# Out:
#     year  Drought_Events  Flood_Events  Freeze_Events  Severe_Storm_Events  \
# 0   2021               1             2              0                   11
# 1   2020               1             0              0                   13
# 2   2019               0             3              0                    8
# 3   2018               1             0              0                    8
# 4   2017               1             2              1                    8
# 5   2016               1             4              0                    8
# 6   2015               1             2              0                    6
# 7   2014               1             1              0                    6
# 8   2013               1             2              0                    7
# 9   2012               1             0              0                    7
# 10  2011               1             2              0                    9
# ...

# %%
df = bd_weather_df 
df.plot(figsize = (15,10), x ='year', y = ['Drought_Events'])
# plt.show()
# Import the style from Matplotlib.
from matplotlib import style
# Use the graph style fivethirtyeight.
style.use('fivethirtyeight')

# %%
df = bd_weather_df 
df.plot(figsize = (15,10), x ='year', y = ['Flood_Events'])
# plt.show()
# Import the style from Matplotlib.
from matplotlib import style
# Use the graph style fivethirtyeight.
style.use('fivethirtyeight')

# %%
df = bd_weather_df 
df.plot(figsize = (15,10), x ='year', y = ['Severe_Storm_Events'])
# plt.show()
# Import the style from Matplotlib.
from matplotlib import style
# Use the graph style fivethirtyeight.
style.use('fivethirtyeight')

# %%
JNorth1996_2020_site_summary= pd.merge(JNorth1996_2020_site_summary, bd_weather_df, how="left", on=["year", "year"])
JNorth1996_2020_site_summary.tail(30)
# Out:
#       month  year                        species   lat_range  sighting_dates  \
# 5785     12  2019            Monarch Egg Sighted   25+_TO_30               4
# 5786     12  2019            Monarch Egg Sighted   30+_TO_35               1
# 5787     12  2019  Monarch Larva (FIRST sighted)   30+_TO_35               1
# 5788     12  2019          Monarch Larva Sighted   25+_TO_30              20
# 5789     12  2019          Monarch Larva Sighted   30+_TO_35              13
# 5790     12  2019          Monarch Larva Sighted   35+_TO_40               1
# 5791     12  2019        Monarch, Captive-Reared   25+_TO_30               2
# 5792     12  2019        Monarch, Captive-Reared   30+_TO_35              25
# 5793     12  2019        Monarch, Captive-Reared   35+_TO_40               1
# 5794     12  2020   Monarch (OTHER Observations)   20+_TO_25               1
# 5795     12  2020   Monarch (OTHER Observations)   25+_TO_30               6
# ...

# %%
df = JNorth1996_2020_site_summary
df.plot(figsize = (15,10), x ='year', y = ['Drought_Events','Hectares_Occupied_End'])
# plt.show()
# Import the style from Matplotlib.
from matplotlib import style
# Use the graph style fivethirtyeight.
style.use('fivethirtyeight')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_13188/1929287516.py in <module>
#       1 df = JNorth1996_2020_site_summary
# ----> 2 df.plot(figsize = (15,10), x ='year', y = ['Drought_Events','Hectares_Occupied_End'])
#       3 # plt.show()
#       4 # Import the style from Matplotlib.
#       5 from matplotlib import style
#
# ~\anaconda3\envs\mlenv\lib\site-packages\pandas\plotting\_core.py in __call__(self, *args, **kwargs)
#     956
#     957                 # don't overwrite
# --> 958                 data = data[y].copy()
#     959
#     960                 if isinstance(data, ABCSeries):
#
# ~\anaconda3\envs\mlenv\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    3462             if is_iterator(key):
#    3463                 key = list(key)
# -> 3464             indexer = self.loc._get_listlike_indexer(key, axis=1)[1]
# ...

# %%
df = JNorth1996_2020_site_summary
df.plot(figsize = (15,10), x ='year', y = ['Flood_Events','Hectares_Occupied_End'])
# plt.show()
# Import the style from Matplotlib.
from matplotlib import style
# Use the graph style fivethirtyeight.
style.use('fivethirtyeight')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_13188/1975687426.py in <module>
#       1 df = JNorth1996_2020_site_summary
# ----> 2 df.plot(figsize = (15,10), x ='year', y = ['Flood_Events','Hectares_Occupied_End'])
#       3 # plt.show()
#       4 # Import the style from Matplotlib.
#       5 from matplotlib import style
#
# ~\anaconda3\envs\mlenv\lib\site-packages\pandas\plotting\_core.py in __call__(self, *args, **kwargs)
#     956
#     957                 # don't overwrite
# --> 958                 data = data[y].copy()
#     959
#     960                 if isinstance(data, ABCSeries):
#
# ~\anaconda3\envs\mlenv\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    3462             if is_iterator(key):
#    3463                 key = list(key)
# -> 3464             indexer = self.loc._get_listlike_indexer(key, axis=1)[1]
# ...

# %%
df = JNorth1996_2020_site_summary
df.plot(figsize = (15,10), x ='year', y = ['Freeze_Events','Hectares_Occupied_End'])
# plt.show()
# Import the style from Matplotlib.
from matplotlib import style
# Use the graph style fivethirtyeight.
style.use('fivethirtyeight')

# %%
df = JNorth1996_2020_site_summary
df.plot(figsize = (15,10), x ='year', y = ['Severe_Storm_Events','Hectares_Occupied_End'])
# plt.show()
# Import the style from Matplotlib.
from matplotlib import style
# Use the graph style fivethirtyeight.
style.use('fivethirtyeight')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_13188/1091721673.py in <module>
#       1 df = JNorth1996_2020_site_summary
# ----> 2 df.plot(figsize = (15,10), x ='year', y = ['Severe_Storm_Events','Hectares_Occupied_End'])
#       3 # plt.show()
#       4 # Import the style from Matplotlib.
#       5 from matplotlib import style
#
# ~\anaconda3\envs\mlenv\lib\site-packages\pandas\plotting\_core.py in __call__(self, *args, **kwargs)
#     956
#     957                 # don't overwrite
# --> 958                 data = data[y].copy()
#     959
#     960                 if isinstance(data, ABCSeries):
#
# ~\anaconda3\envs\mlenv\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    3462             if is_iterator(key):
#    3463                 key = list(key)
# ...

# %%
df = JNorth1996_2020_site_summary
df.plot(figsize = (15,10), x ='year', y = ['Wildfire_Events','Hectares_Occupied_End'])
# plt.show()
# Import the style from Matplotlib.
from matplotlib import style
# Use the graph style fivethirtyeight.
style.use('fivethirtyeight')

# %%
df = JNorth1996_2020_site_summary
df.plot(figsize = (15,10), x ='year', y = ['Winter_Storm_Events','Hectares_Occupied_End'])
# plt.show()
# Import the style from Matplotlib.
from matplotlib import style
# Use the graph style fivethirtyeight.
style.use('fivethirtyeight')

# %%
df = JNorth1996_2020_site_summary
df.plot(figsize = (15,10), x ='year', y = ['Tropical_Cyclone_Events','Hectares_Occupied_End'])
# plt.show()
# Import the style from Matplotlib.
from matplotlib import style
# Use the graph style fivethirtyeight.
style.use('fivethirtyeight')

# %% [markdown]
# # Pesticide Usage in Tons

# %%
pesticide_use_df = pd.read_csv("../../resources/worldometers_info_pesticide/Pesticides_US_Usage.csv")
pesticide_use_df.head(15)
# Out:
#     Season  Tons_Used
# 0     2021     407779
# 1     2020     407779
# 2     2019     407779
# 3     2018     407779
# 4     2017     407779
# 5     2016     407779
# 6     2015     407779
# 7     2014     407779
# 8     2013     407779
# 9     2012     407779
# 10    2011     391299
# 11    2010     374818
# 12    2009     358338
# 13    2008     379203
# 14    2007     400068

# %%
pesticide_use_df.rename(columns={'Season': 'year'}, inplace=True)
pesticide_use_df.head(15)
# Out:
#     year  Tons_Used
# 0   2021     407779
# 1   2020     407779
# 2   2019     407779
# 3   2018     407779
# 4   2017     407779
# 5   2016     407779
# 6   2015     407779
# 7   2014     407779
# 8   2013     407779
# 9   2012     407779
# 10  2011     391299
# 11  2010     374818
# 12  2009     358338
# 13  2008     379203
# 14  2007     400068

# %%
JNorth1996_2020_summary= pd.merge(JNorth1996_2020_site_summary, pesticide_use_df, how="left", on=["year", "year"])
JNorth1996_2020_summary.tail(30)
# Out:
#       month  year                        species   lat_range  sighting_dates  \
# 5785     12  2019            Monarch Egg Sighted   25+_TO_30               4
# 5786     12  2019            Monarch Egg Sighted   30+_TO_35               1
# 5787     12  2019  Monarch Larva (FIRST sighted)   30+_TO_35               1
# 5788     12  2019          Monarch Larva Sighted   25+_TO_30              20
# 5789     12  2019          Monarch Larva Sighted   30+_TO_35              13
# 5790     12  2019          Monarch Larva Sighted   35+_TO_40               1
# 5791     12  2019        Monarch, Captive-Reared   25+_TO_30               2
# 5792     12  2019        Monarch, Captive-Reared   30+_TO_35              25
# 5793     12  2019        Monarch, Captive-Reared   35+_TO_40               1
# 5794     12  2020   Monarch (OTHER Observations)   20+_TO_25               1
# 5795     12  2020   Monarch (OTHER Observations)   25+_TO_30               6
# ...

# %%
df =JNorth1996_2020_summary
df.plot(figsize = (10,2), x ='year', y = ['Tons_Used','Hectares_Occupied_End'])
# plt.show()
# Import the style from Matplotlib.
from matplotlib import style
# Use the graph style fivethirtyeight.
style.use('fivethirtyeight')

# %%
str(JNorth1996_2020_summary.columns.tolist())
# Out:
# "['month', 'year', 'species', 'lat_range', 'sighting_dates', 'number', 'sighting_distinct_dates', 'sites', 'Season_End', 'Hectares_Occupied_Start', 'Hectares_Occupied_End', 'Drought_Events', 'Flood_Events', 'Freeze_Events', 'Severe_Storm_Events ', 'Tropical_Cyclone_Events', 'Wildfire_Events', 'Winter_Storm_Events', 'Tons_Used']"

# %% [markdown]
# # Output CSVs

# %%
JNorth1996_2020_summary.shape
# Out:
# (5815, 19)

# %%
JNorth1996_2020_summary.to_csv('JNorth_Summary.csv', header=True, mode='w', index=False)

# %%
MWatch_TR_Mex_df.shape
# Out:
# (81, 7)

# %%
MWatch_TR_Mex_df.to_csv('MWatch_TR_Mex_Site_Summary.csv', header=True, mode='w', index=False)
